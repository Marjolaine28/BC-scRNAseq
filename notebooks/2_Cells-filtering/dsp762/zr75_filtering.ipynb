# %%
# %load_ext autoreload
# %autoreload 1
# %autosave 60
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Autosaving every 60 seconds

# %%
import sys
import pandas as pd
import numpy as np
import importlib
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, PowerNorm
import scanpy
import gseapy as gp

# %%
sys.path.append("/u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/")

# %%
import rnaseq
importlib.reload(rnaseq)
# Out:
# <module 'rnaseq' from '/u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/rnaseq/__init__.py'>

# %%
# %%bash
# pwd
# Out:
# /u/davidm/Documents/Master-thesis/Projects/scBC-Analysis/0_Preprocessing/2_Cells-filtering/dsp762

# %%
# %%bash
# tar czf ./figs.tar.gz ./figs/*.pdf

# %% [markdown]
# ### Plotting parameters

# %%
# %matplotlib inline
plt.rcParams['figure.dpi'] = 110
plt.rcParams['font.size'] = 6

# %% [markdown]
# ### Genes lists

# %%
cell_cycle_genes = np.array(['MCM5', 'PCNA', 'TYMS', 'FEN1', 'MCM2', 'MCM4', 'RRM1', 'UNG',
       'GINS2', 'MCM6', 'CDCA7', 'DTL', 'PRIM1', 'UHRF1', 'HELLS', 'RFC2',
       'RPA2', 'NASP', 'RAD51AP1', 'GMNN', 'WDR76', 'SLBP', 'CCNE2',
       'UBR7', 'POLD3', 'MSH2', 'ATAD2', 'RAD51', 'RRM2', 'CDC45', 'CDC6',
       'EXO1', 'TIPIN', 'DSCC1', 'BLM', 'CASP8AP2', 'USP1', 'CLSPN',
       'POLA1', 'CHAF1B', 'BRIP1', 'E2F8', 'HMGB2', 'CDK1', 'NUSAP1',
       'UBE2C', 'BIRC5', 'TPX2', 'TOP2A', 'NDC80', 'CKS2', 'NUF2',
       'CKS1B', 'MKI67', 'TMPO', 'CENPF', 'TACC3', 'SMC4', 'CCNB2',
       'CKAP2L', 'CKAP2', 'AURKB', 'BUB1', 'KIF11', 'ANP32E', 'TUBB4B',
       'GTSE1', 'KIF20B', 'HJURP', 'CDCA3', 'CDC20', 'TTK', 'CDC25C',
       'KIF2C', 'RANGAP1', 'NCAPD2', 'DLGAP5', 'CDCA2', 'CDCA8', 'ECT2',
       'KIF23', 'HMMR', 'AURKA', 'PSRC1', 'ANLN', 'LBR', 'CKAP5', 'CENPE',
       'CTCF', 'NEK2', 'G2E3', 'GAS2L3', 'CBX5', 'CENPA'])

s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]

# %%
g2m_genes = ['ABL1', 'AMD1', 'ARID4A', 'ATF5', 'ATRX', 'AURKA', 'AURKB',
       'BARD1', 'BCL3', 'BIRC5', 'BRCA2', 'BUB1', 'BUB3', 'CASP8AP2',
       'CBX1', 'CCNA2', 'CCNB2', 'CCND1', 'CCNF', 'CCNT1', 'CDC20',
       'CDC25A', 'CDC25B', 'CDC27', 'CDC45', 'CDC6', 'CDC7', 'CDK1',
       'CDK4', 'CDKN1B', 'CDKN2C', 'CDKN3', 'CENPA', 'CENPE', 'CENPF',
       'CHAF1A', 'CHEK1', 'CHMP1A', 'CKS1B', 'CKS2', 'CTCF', 'CUL1',
       'CUL3', 'CUL4A', 'CUL5', 'DBF4', 'DDX39A', 'DKC1', 'DMD', 'DR1',
       'DTYMK', 'E2F1', 'E2F2', 'E2F3', 'E2F4', 'EFNA5', 'EGF', 'ESPL1',
       'EWSR1', 'EXO1', 'EZH2', 'FANCC', 'FBXO5', 'FOXN3', 'G3BP1',
       'GINS2', 'GSPT1', 'H2AX', 'H2AZ1', 'H2AZ2', 'H2BC12', 'HIF1A',
       'HIRA', 'HMGA1', 'HMGB3', 'HMGN2', 'HMMR', 'HNRNPD', 'HNRNPU',
       'HOXC10', 'HSPA8', 'HUS1', 'ILF3', 'INCENP', 'JPT1', 'KATNA1',
       'KIF11', 'KIF15', 'KIF20B', 'KIF22', 'KIF23', 'KIF2C', 'KIF4A',
       'KIF5B', 'KMT5A', 'KNL1', 'KPNA2', 'KPNB1', 'LBR', 'LIG3', 'LMNB1',
       'MAD2L1', 'MAP3K20', 'MAPK14', 'MARCKS', 'MCM2', 'MCM3', 'MCM5',
       'MCM6', 'MEIS1', 'MEIS2', 'MKI67', 'MNAT1', 'MT2A', 'MTF2',
       'MYBL2', 'MYC', 'NASP', 'NCL', 'NDC80', 'NEK2', 'NOLC1', 'NOTCH2',
       'NSD2', 'NUMA1', 'NUP50', 'NUP98', 'NUSAP1', 'ODC1', 'ODF2',
       'ORC5', 'ORC6', 'PAFAH1B1', 'PBK', 'PDS5B', 'PLK1', 'PLK4', 'PML',
       'POLA2', 'POLE', 'POLQ', 'PRC1', 'PRIM2', 'PRMT5', 'PRPF4B',
       'PTTG1', 'PTTG3P', 'PURA', 'RACGAP1', 'RAD21', 'RAD23B', 'RAD54L',
       'RASAL2', 'RBL1', 'RBM14', 'RPA2', 'RPS6KA5', 'SAP30', 'SFPQ',
       'SLC12A2', 'SLC38A1', 'SLC7A1', 'SLC7A5', 'SMAD3', 'SMARCC1',
       'SMC1A', 'SMC2', 'SMC4', 'SNRPD1', 'SQLE', 'SRSF1', 'SRSF10',
       'SRSF2', 'SS18', 'STAG1', 'STIL', 'STMN1', 'SUV39H1', 'SYNCRIP',
       'TACC3', 'TENT4A', 'TFDP1', 'TGFB1', 'TLE3', 'TMPO', 'TNPO2',
       'TOP1', 'TOP2A', 'TPX2', 'TRA2B', 'TRAIP', 'TROAP', 'TTK', 'UBE2C',
       'UBE2S', 'UCK2', 'UPF1', 'WRN', 'XPO1', 'YTHDC1']

# %% [markdown]
# ### Load sample

# %%
sample = "Sample_ZR75"
new_sample_name = "ZR75"
quant_params = "trimmed-reads-cutadapt-all/decoys-k19-1.4.0/customWh-top-3000"
genref = "human/assembly__GRCh38-hg38/annotation__gencode/gencode_34"
project = "dsp762"
cell_line = "ZR75"

# %%
sc = rnaseq.readwrite.read_raw(project_id  = project, quant_tool = "alevin", samples = sample, genes_id = "ensembl_gene_id", quant_params = quant_params, genref = genref, cdna = "3' tag", exp = "sc")
sc.obs_names = sc.obs["CB"].tolist()
# Out:
# /home/arion/davidm/Data/datasets/raw/private/RNA-seq/sc/dsp762/quant/alevin/human/assembly__GRCh38-hg38/annotation__gencode/gencode_34/trimmed-reads-cutadapt-all/decoys-k19-1.4.0/customWh-top-3000
# Using BioMart Ensembl Genes 100 hsapiens_gene_ensembl for gene annotations.

# %%
rnaseq.setup.annotate_samples(sc, samples_annot_name = "samples", samples_annot = new_sample_name, ow = True)
rnaseq.setup.annotate_samples(sc, samples_annot_name = "cell_line", samples_annot = cell_line, ow = True)

rnaseq.setup.annotate_samples(sc, samples_annot_name = "total_UMIs", samples_annot = sc.X.toarray().sum(1).ravel())
rnaseq.setup.annotate_samples(sc, samples_annot_name = "#_genes", samples_annot = (sc.X.toarray() != 0).sum(1).ravel())
rnaseq.setup.annotate_samples(sc, samples_annot_name = "max_corr")
rnaseq.setup.annotate_samples(sc, samples_annot_name = "mt_frac")
rnaseq.setup.annotate_samples(sc, samples_annot_name = "rp_frac")

rnaseq.setup.annotate_genes(sc, "gene_biotype")
# Out:
# Annotating samples...
# Annotating cell_line...
# Annotating total_UMIs...
# Annotating #_genes...
# Annotating max_corr...
# Normalization by total UMIs...
# Log2 + 1 tranformation...
# Annotating mt_frac...
# Annotating chromosome_name using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...
# Annotating rp_frac...
# Annotating external_gene_name using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...
# Annotating gene_biotype using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...

# %%
sc._inplace_subset_obs(sc.obs["total_UMIs"] > 100)

# %%
sc.X.shape
# Out:
# (1771, 60240)

# %%
# x = sc.layers["raw"].toarray()[:, (sc.var["gene_biotype"] == "lncRNA") & (sc.var["external_gene_name"] != "MALAT1")]
x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "lncRNA"]
sc.obs["lncRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "rRNA"]
sc.obs["rRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "Mt_rRNA"]
sc.obs["Mt_rRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "protein_coding"]
sc.obs["protein_coding"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "processed_pseudogene"]
sc.obs["processed_pseudogene"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, [g.startswith("HSP") for g in sc.var["external_gene_name"]]]
sc.obs["hsp_frac"] = x.sum(1) / sc.obs["total_UMIs"]

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)

sc.var_names = sc.var["external_gene_name"].values
sc.var_names = np.array(sc.var_names.values)
sc.var_names_make_unique()
scanpy.tl.score_genes_cell_cycle(sc, s_genes=s_genes, g2m_genes=g2m_genes)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc_copy = sc.copy()

# %% [markdown]
# ### QC distributions

# %%
sc = sc_copy.copy()

# %%
plt.boxplot(sc.obs["total_UMIs"]);

# %%
_,ax = plt.subplots(figsize=(2.5,2))
rnaseq.plotting.loghist(sc.obs["total_UMIs"], bins=20, ax=ax, linewidth=0.1, edgecolor='black', fc = "white");
# ax.set_xlim(200,25000)
plt.axvline(2000, linewidth = 0.8, c = 'red')
plt.title(new_sample_name)
plt.ylabel("Fréquence")
plt.xlabel("Nombre de UMI")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Nombre de UMI')

# %%
_,ax = plt.subplots(figsize=(2.5,2))
plt.hist(sc.obs["max_corr"], bins=20, linewidth=0.1, edgecolor='black', fc = "white");
plt.title(new_sample_name)
plt.axvline(0.7, linewidth = 0.8, c = 'red')
plt.ylabel("Fréquence")
plt.xlabel("Rmax")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Rmax')

# %%
_,ax = plt.subplots(figsize=(2.5,2))
plt.hist(sc.obs["Mt_rRNA"], bins=20, linewidth=0.1, edgecolor='black', fc = "white");
plt.title(new_sample_name)
plt.axvline(0.03, linewidth = 0.8, c = 'red')
plt.ylabel("Fréquence")
plt.xlabel("Fraction de Mt_rRNA")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Fraction de Mt_rRNA')

# %% [markdown]
# ### Explore sample

# %%
sc = sc_copy.copy()

# %%
metrics = ['total_UMIs', '#_genes', 'max_corr', 'MappingRate','DedupRate', 'mt_frac', 'rp_frac']
powers_metrics = [0.1,0.3,0.8,1.3,1.5,0.5,1.2]

biotypes = ['rRNA', 'Mt_rRNA', 'lncRNA', 'processed_pseudogene', 'protein_coding', 'G2M_score', 'hsp_frac', 'marker']
powers_biotypes = [1,0.5,0.5,0.5,1.8,0.5, 0.5, 1]

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)
scanpy.pp.pca(sc, n_comps=50)
scanpy.pp.neighbors(sc, n_pcs=20, n_neighbors=15)
scanpy.tl.umap(sc, n_components=2)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc.obs["marker"] = sc.X.toarray()[:, sc.var["external_gene_name"].values == "ALDOA"] # HSPA5 SERP1

# %%
scatt = plt.subplots(figsize=(10,2.5), sharey=True)
for i,(c,p) in enumerate(zip(biotypes,powers_biotypes)):
    axi = plt.subplot(2,9,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 2, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(biotypes):
    axi = plt.subplot(2,9,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    plt.hist(sc.obs[c],  bins = 20, color="white", edgecolor="gray", linewidth = 0.3);

# %%
scatt = plt.subplots(figsize=(9.5,2.5), sharey=True)
for i,(c,p) in enumerate(zip(metrics,powers_metrics)):
    axi = plt.subplot(2,8,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 1.5, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(metrics):
    axi = plt.subplot(2,8,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    if c in ["total_UMIs", "#_genes"] :
        rnaseq.plotting.loghist(sc.obs[c], bins=20, ax=axi, linewidth=0.3, color="white", edgecolor="gray");
    else :
        plt.hist(sc.obs[c],  bins = 15, color="white", edgecolor="gray", linewidth = 0.3);

# %% [markdown]
# ### Filter sample

# %%
sc = sc_copy.copy()

# %%
sc._inplace_subset_obs(sc.obs["total_UMIs"] > 1500)
sc._inplace_subset_obs(sc.obs["mt_frac"] < 0.1)

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)
scanpy.pp.pca(sc, n_comps=50)
scanpy.pp.neighbors(sc, n_pcs=20, n_neighbors=15)
scanpy.tl.umap(sc, n_components=2)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc.obs["marker"] = sc.X.toarray()[:, sc.var["external_gene_name"].values == "SPDEF"] # ENO1 ALDO1

# %%
scatt = plt.subplots(figsize=(10,2.5), sharey=True)
for i,(c,p) in enumerate(zip(biotypes,powers_biotypes)):
    axi = plt.subplot(2,9,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 2, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(biotypes):
    axi = plt.subplot(2,9,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    plt.hist(sc.obs[c],  bins = 20, color="white", edgecolor="gray", linewidth = 0.3);

# %%
scatt = plt.subplots(figsize=(9.5,2.5), sharey=True)
for i,(c,p) in enumerate(zip(metrics,powers_metrics)):
    axi = plt.subplot(2,8,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 1.5, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(metrics):
    axi = plt.subplot(2,8,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    if c in ["total_UMIs", "#_genes"] :
        rnaseq.plotting.loghist(sc.obs[c], bins=20, ax=axi, linewidth=0.3, color="white", edgecolor="gray");
    else :
        plt.hist(sc.obs[c],  bins = 15, color="white", edgecolor="gray", linewidth = 0.3);

# %%
sc.X.shape
# Out:
# (1529, 60240)

# %% [markdown]
# ### Save filtered data

# %%
rnaseq.readwrite.write_filtered(sc)
# Out:
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'samples' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'project_id' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cell_line' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'phase' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromosome_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'external_gene_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_biotype' as categorical

# %%
del sc, sc_copy

# %% [markdown]
# ### Heterogeneity analysis

# %%
sc = rnaseq.readwrite.read_filtered(samples = {project : new_sample_name})

# %%
scanpy.tl.leiden(sc, resolution=0.3)

scatt,_ = plt.subplots(figsize=(3,2))

rnaseq.plotting.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], color = sc.obs["leiden"], \
    s = 20, xlabel="UMAP1", ylabel="UMAP2", color_title = "clusters",\
    title = new_sample_name, linewidth=0.15, fig = scatt)

# %%
rnaseq.setup.annotate_genes(sc, 'description')
# Out:
# Annotating description using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...

# %%
gene_exp = pd.DataFrame(sc.X.toarray().T, columns = sc.obs["CB"].values)
class_vector = (sc.obs["leiden"].values == '3').astype(str)
class_vector = np.where(class_vector == 'True', "cluster", class_vector) 
class_vector = np.where(class_vector == 'False', "rest", class_vector)

# %%
idx = np.argsort(class_vector)
gene_exp = gene_exp[gene_exp.columns[idx]]
gene_exp.insert(0, "DESCRIPTION", sc.var["description"].values, True)
gene_exp.insert(0, "NAME", sc.var["external_gene_name"].values, True)

class_vector = list(class_vector[idx])

# %%
gs_res = gp.gsea(gene_exp, # ordata='./P53_resampling_data.txt'
                 'MSigDB_Hallmark_2020', # enrichr library names
                  class_vector,
                 # set permutation_type to phenotype if samples >=15
                 permutation_type='phenotype',
                 permutation_num=100, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 method='signal_to_noise',
                 processes=4, seed= 7,
                 format='png')
# Out:
# 2021-12-15 10:50:12,777 Warning: dropping duplicated gene names, only keep the first values

# %%
res = gs_res.res2d.sort_values(by='nes', ascending=False)
res = res.loc[res.index[(res['fdr'].values < 0.05) & (res['pval'].values < 0.05)]]

# %%
res #2
# Out:
#                                          es       nes      pval       fdr  \
# Term
# E2F Targets                        0.900053  3.443313  0.000000  0.000000
# DNA Repair                         0.700866  3.442409  0.000000  0.000000
# G2-M Checkpoint                    0.810293  3.431491  0.000000  0.000000
# UV Response Up                     0.596642  3.045767  0.000000  0.000000
# Spermatogenesis                    0.656902  2.983492  0.000000  0.000000
# Myc Targets V1                     0.720527  2.971651  0.000000  0.000000
# Mitotic Spindle                    0.621767  2.790611  0.000000  0.000000
# mTORC1 Signaling                   0.549378  2.598933  0.000000  0.000000
# Myc Targets V2                     0.649774  2.566192  0.000000  0.000000
# Unfolded Protein Response          0.569487  2.546386  0.000000  0.000000
# PI3K/AKT/mTOR  Signaling           0.520440  2.473727  0.000000  0.000000
# p53 Pathway                        0.427636  2.295957  0.000000  0.000000
# Estrogen Response Late             0.407200  2.187892  0.000000  0.000000
# Apoptosis                          0.426515  2.173328  0.000000  0.000000
# Interferon Gamma Response          0.400532  2.163554  0.000000  0.000000
# Oxidative Phosphorylation          0.451614  2.012421  0.000000  0.004524
# Fatty Acid Metabolism              0.402587  1.964454  0.000000  0.006387
# Xenobiotic Metabolism              0.376485  1.934942  0.000000  0.006032
# Glycolysis                         0.380324  1.893254  0.000000  0.005714
# Allograft Rejection                0.365106  1.751894  0.000000  0.009048
# Cholesterol Homeostasis            0.443166  1.735787  0.000000  0.008617
# Epithelial Mesenchymal Transition  0.328888  1.657732  0.000000  0.018095
# KRAS Signaling Dn                  0.272485  1.652335  0.000000  0.017308
# Pperoxisome                        0.369393  1.636434  0.000000  0.016587
# Adipogenesis                       0.320771  1.615565  0.000000  0.017371
# IL-6/JAK/STAT3 Signaling           0.324203  1.569834  0.000000  0.026447
# Complement                         0.287085  1.524040  0.000000  0.032169
# Reactive Oxygen Species Pathway    0.394472  1.523482  0.000000  0.031020
# heme Metabolism                    0.300564  1.505606  0.000000  0.031199
# IL-2/STAT5 Signaling               0.283884  1.493344  0.000000  0.031521
# Wnt-beta Catenin Signaling         0.384674  1.453089  0.000000  0.040714
# Hypoxia                           -0.310757 -1.542678  0.043478  0.048714
# TNF-alpha Signaling via NF-kB     -0.337462 -1.713371  0.000000  0.009821
# Androgen Response                 -0.404248 -1.778138  0.000000  0.007857
# Protein Secretion                 -0.397183 -1.831319  0.000000  0.003929
# Estrogen Response Early           -0.421998 -2.066942  0.000000  0.000000
#
#                                    geneset_size  matched_size  \
# Term
# E2F Targets                                 200           200
# DNA Repair                                  150           146
# G2-M Checkpoint                             200           199
# UV Response Up                              158           135
# Spermatogenesis                             135            72
# Myc Targets V1                              200           200
# Mitotic Spindle                             199           197
# mTORC1 Signaling                            200           194
# Myc Targets V2                               58            58
# Unfolded Protein Response                   113           110
# PI3K/AKT/mTOR  Signaling                    105            93
# p53 Pathway                                 200           181
# Estrogen Response Late                      200           176
# Apoptosis                                   161           124
# Interferon Gamma Response                   200           140
# Oxidative Phosphorylation                   200           197
# Fatty Acid Metabolism                       158           129
# Xenobiotic Metabolism                       200           134
# Glycolysis                                  200           172
# Allograft Rejection                         200            90
# Cholesterol Homeostasis                      74            65
# Epithelial Mesenchymal Transition           200           101
# KRAS Signaling Dn                           200           100
# Pperoxisome                                 104            89
# Adipogenesis                                200           172
# IL-6/JAK/STAT3 Signaling                     87            54
# Complement                                  200           128
# Reactive Oxygen Species Pathway              49            44
# heme Metabolism                             200           159
# IL-2/STAT5 Signaling                        199           140
# Wnt-beta Catenin Signaling                   42            32
# Hypoxia                                     200           154
# TNF-alpha Signaling via NF-kB               200           157
# Androgen Response                           100            93
# Protein Secretion                            96            94
# Estrogen Response Early                     200           181
#
#                                                                                genes  \
# Term
# E2F Targets                        RRM2;UBE2T;ATAD2;PCNA;HMGB2;DUT;CDK1;RANBP1;CK...
# DNA Repair                         PCNA;DUT;ZWINT;TYMS;RFC2;PRIM1;RFC4;FEN1;RFC3;...
# G2-M Checkpoint                    EXO1;CDK1;CKS1B;EZH2;H2AZ1;GINS2;STMN1;SMC4;TO...
# UV Response Up                     RFC4;FEN1;BTG3;H2AX;PARP2;ATF3;CDK2;CEBPG;ASNS...
# Spermatogenesis                    CDK1;EZH2;RFC4;PARP2;TOPBP1;DBF4;NCAPH;PSMG1;C...
# Myc Targets V1                     PCNA;DUT;RANBP1;TYMS;MCM7;H2AZ1;MCM4;RFC4;DEK;...
# Mitotic Spindle                    CDK1;SMC4;TOP2A;FBXO5;PRC1;SMC3;NUSAP1;KIF15;K...
# mTORC1 Signaling                   RRM2;DHFR;MCM4;MCM2;TUBG1;CACYBP;CDKN1A;TMEM97...
# Myc Targets V2                     MCM4;MCM5;PA2G4;TMEM97;CDK4;NOLC1;UNG;TCOF1;PL...
# Unfolded Protein Response          CKS1B;FUS;EIF4EBP1;H2AX;LSM4;ATF3;CEBPG;EXOSC9...
# PI3K/AKT/mTOR  Signaling           CDK1;CDKN1A;CDK2;CDK4;PPP1CA;E2F1;SFN;CALR;PFN...
# p53 Pathway                        PCNA;RAD51C;CDKN1A;ATF3;CCP110;SPHK1;RAD9A;CDK...
# Estrogen Response Late             GINS2;TOP2A;CDC6;RNASEH2A;BTG3;IL17RB;RBBP8;IM...
# Apoptosis                          HMGB2;BRCA1;TOP2A;BTG3;CDKN1A;ATF3;CDK2;EBP;SL...
# Interferon Gamma Response          CDKN1A;MTHFD2;PNP;ISOC1;PLSCR1;OAS3;PFKP;PIM1;...
# Oxidative Phosphorylation          HSPA9;CYCS;SLC25A5;FH;VDAC3;MRPS11;NDUFS8;ECHS...
# Fatty Acid Metabolism              H2AZ1;NCAPH2;HADH;FH;YWHAH;HSP90AA1;ACAT2;ECHS...
# Xenobiotic Metabolism              TMEM97;MTHFD1;HPRT1;SHMT2;HES6;GSTO1;DCXR;GART...
# Glycolysis                         CDK1;STMN1;NASP;POLR3K;CLN6;KIF2A;SLC25A10;PGA...
# Allograft Rejection                BRCA1;AARS1;CDKN2A;CCND3;TRAF2;NME1;FAS;AKT1;U...
# Cholesterol Homeostasis            TMEM97;ATF3;FABP5;EBP;ANXA5;FDPS;ACAT2;FADS2;P...
# Epithelial Mesenchymal Transition  MCM7;APLP1;CALU;PLOD2;ITGB1;LAMA3;AREG;ENO2;FA...
# KRAS Signaling Dn                  RIBC2;BARD1;GAMT;CALCB;C5;GTF3C5;FGFR3;NUDT11;...
# Pperoxisome                        TOP2A;MSH2;CLN6;YWHAH;SLC25A19;FDPS;ISOC1;CTPS...
# Adipogenesis                       HADH;SLC25A10;PLIN2;CDKN2C;ATP1B3;AK2;ECHS1;CH...
# IL-6/JAK/STAT3 Signaling           IL17RB;PIM1;FAS;GRB2;PTPN11;HAX1;TYK2;TNFRSF12...
# Complement                         CALM1;CTSV;KIF2A;ANXA5;PFN1;PLSCR1;CALM3;PIM1;...
# Reactive Oxygen Species Pathway    CDKN2D;PFKP;SOD2;NDUFA6;PRDX2;GLRX2;GPX4;PRDX4...
# heme Metabolism                    H4C3;GMPS;ASNS;SLC10A3;E2F2;RAD23A;CCND3;UBAC1...
# IL-2/STAT5 Signaling               CDC6;PNP;PLIN2;APLP1;PLSCR1;PHTF2;CCND3;GSTO1;...
# Wnt-beta Catenin Signaling         SKP2;JAG2;LEF1;CUL1;HEY2;DVL2;NOTCH1;HDAC2;GNA...
# Hypoxia                            CDKN1A;ATF3;PLIN2;PFKP;CSRP2;PIM1;SLC25A1;DDIT...
# TNF-alpha Signaling via NF-kB      BTG3;CDKN1A;ATF3;SPHK1;PHLDA2;TNFAIP8;SOD2;ARE...
# Androgen Response                  PA2G4;CENPN;XRCC5;UBE2I;FKBP5;CCND3;TNFAIP8;SP...
# Protein Secretion                  ANP32E;RER1;TMX1;AP2S1;GLA;LMAN1;M6PR;GBF1;ZW1...
# Estrogen Response Early            IL17RB;RBBP8;MYBL1;ARL3;SFN;FKBP5;PPIF;CLDN7;O...
#
#                                                                          ledge_genes
# Term
# E2F Targets                        RRM2;UBE2T;ATAD2;PCNA;HMGB2;DUT;CDK1;RANBP1;CK...
# DNA Repair                         PCNA;DUT;ZWINT;TYMS;RFC2;PRIM1;RFC4;FEN1;RFC3;...
# G2-M Checkpoint                    EXO1;CDK1;CKS1B;EZH2;H2AZ1;GINS2;STMN1;SMC4;TO...
# UV Response Up                     RFC4;FEN1;BTG3;H2AX;PARP2;ATF3;CDK2;CEBPG;ASNS...
# Spermatogenesis                    CDK1;EZH2;RFC4;PARP2;TOPBP1;DBF4;NCAPH;PSMG1;C...
# Myc Targets V1                     PCNA;DUT;RANBP1;TYMS;MCM7;H2AZ1;MCM4;RFC4;DEK;...
# Mitotic Spindle                    CDK1;SMC4;TOP2A;FBXO5;PRC1;SMC3;NUSAP1;KIF15;K...
# mTORC1 Signaling                   RRM2;DHFR;MCM4;MCM2;TUBG1;CACYBP;CDKN1A;TMEM97...
# Myc Targets V2                     MCM4;MCM5;PA2G4;TMEM97;CDK4;NOLC1;UNG;TCOF1;PL...
# Unfolded Protein Response          CKS1B;FUS;EIF4EBP1;H2AX;LSM4;ATF3;CEBPG;EXOSC9...
# PI3K/AKT/mTOR  Signaling           CDK1;CDKN1A;CDK2;CDK4;PPP1CA;E2F1;SFN;CALR;PFN...
# p53 Pathway                        PCNA;RAD51C;CDKN1A;ATF3;CCP110;SPHK1;RAD9A;CDK...
# Estrogen Response Late             GINS2;TOP2A;CDC6;RNASEH2A;BTG3;IL17RB;RBBP8;IM...
# Apoptosis                          HMGB2;BRCA1;TOP2A;BTG3;CDKN1A;ATF3;CDK2;EBP;SL...
# Interferon Gamma Response          CDKN1A;MTHFD2;PNP;ISOC1;PLSCR1;OAS3;PFKP;PIM1;...
# Oxidative Phosphorylation          HSPA9;CYCS;SLC25A5;FH;VDAC3;MRPS11;NDUFS8;ECHS...
# Fatty Acid Metabolism              H2AZ1;NCAPH2;HADH;FH;YWHAH;HSP90AA1;ACAT2;ECHS...
# Xenobiotic Metabolism              TMEM97;MTHFD1;HPRT1;SHMT2;HES6;GSTO1;DCXR;GART...
# Glycolysis                         CDK1;STMN1;NASP;POLR3K;CLN6;KIF2A;SLC25A10;PGA...
# Allograft Rejection                BRCA1;AARS1;CDKN2A;CCND3;TRAF2;NME1;FAS;AKT1;U...
# Cholesterol Homeostasis            TMEM97;ATF3;FABP5;EBP;ANXA5;FDPS;ACAT2;FADS2;P...
# Epithelial Mesenchymal Transition  MCM7;APLP1;CALU;PLOD2;ITGB1;LAMA3;AREG;ENO2;FA...
# KRAS Signaling Dn                  RIBC2;BARD1;GAMT;CALCB;C5;GTF3C5;FGFR3;NUDT11;...
# Pperoxisome                        TOP2A;MSH2;CLN6;YWHAH;SLC25A19;FDPS;ISOC1;CTPS...
# Adipogenesis                       HADH;SLC25A10;PLIN2;CDKN2C;ATP1B3;AK2;ECHS1;CH...
# IL-6/JAK/STAT3 Signaling           IL17RB;PIM1;FAS;GRB2;PTPN11;HAX1;TYK2;TNFRSF12...
# Complement                         CALM1;CTSV;KIF2A;ANXA5;PFN1;PLSCR1;CALM3;PIM1;...
# Reactive Oxygen Species Pathway    CDKN2D;PFKP;SOD2;NDUFA6;PRDX2;GLRX2;GPX4;PRDX4...
# heme Metabolism                    H4C3;GMPS;ASNS;SLC10A3;E2F2;RAD23A;CCND3;UBAC1...
# IL-2/STAT5 Signaling               CDC6;PNP;PLIN2;APLP1;PLSCR1;PHTF2;CCND3;GSTO1;...
# Wnt-beta Catenin Signaling                             SKP2;JAG2;LEF1;CUL1;HEY2;DVL2
# Hypoxia                            ANGPTL4;ENO1;SCARB1;NDRG1;GCNT2;ZNF292;ATP7A;E...
# TNF-alpha Signaling via NF-kB      EIF1;TANK;SMAD3;TRIB1;NFKBIE;EDN1;LDLR;SLC2A6;...
# Androgen Response                  ACSL3;ADAMTS1;DNAJB9;SLC26A2;PGM3;ZMIZ1;UAP1;L...
# Protein Secretion                  ARF1;COPB1;GOLGA4;ATP7A;BNIP3;SEC31A;RAB14;USO...
# Estrogen Response Early            ELF1;PTGES;AR;PEX11A;HES1;UGCG;DEPTOR;RAB17;SI...

# %%
res #3
# Out:
#                                          es       nes      pval       fdr  \
# Term
# Hypoxia                            0.794740  3.656446  0.000000  0.000000
# Glycolysis                         0.556500  2.871330  0.000000  0.000000
# TNF-alpha Signaling via NF-kB      0.509653  2.357446  0.000000  0.000000
# Epithelial Mesenchymal Transition  0.354941  1.818690  0.000000  0.010893
# Estrogen Response Early            0.364548  1.753779  0.000000  0.008715
# Androgen Response                  0.372562  1.614913  0.000000  0.031124
# KRAS Signaling Up                  0.362254  1.613591  0.000000  0.027233
# UV Response Dn                     0.315746  1.574359  0.000000  0.038732
# Apoptosis                         -0.340985 -1.508426  0.032258  0.044169
# Complement                        -0.386699 -1.564983  0.023810  0.026501
# Adipogenesis                      -0.374974 -1.747301  0.000000  0.002989
# Fatty Acid Metabolism             -0.414907 -1.840004  0.000000  0.001052
# Bile Acid Metabolism              -0.446495 -1.840599  0.000000  0.001114
# Estrogen Response Late            -0.423219 -1.935838  0.000000  0.000000
# Pperoxisome                       -0.459775 -1.971067  0.000000  0.000000
# mTORC1 Signaling                  -0.402252 -1.981719  0.000000  0.000000
# Reactive Oxygen Species Pathway   -0.478397 -1.987339  0.000000  0.000000
# UV Response Up                    -0.404614 -1.988870  0.000000  0.000000
# Cholesterol Homeostasis           -0.532888 -2.017052  0.000000  0.000000
# Xenobiotic Metabolism             -0.456058 -2.051681  0.000000  0.000000
# Unfolded Protein Response         -0.459209 -2.102199  0.000000  0.000000
# Spermatogenesis                   -0.511545 -2.255488  0.000000  0.000000
# Mitotic Spindle                   -0.521342 -2.422538  0.000000  0.000000
# DNA Repair                        -0.530842 -2.527141  0.000000  0.000000
# Myc Targets V2                    -0.653375 -2.725049  0.000000  0.000000
# Myc Targets V1                    -0.588095 -2.759238  0.000000  0.000000
# E2F Targets                       -0.793830 -2.835691  0.000000  0.000000
# G2-M Checkpoint                   -0.752612 -2.914111  0.000000  0.000000
# Oxidative Phosphorylation         -0.611047 -2.967920  0.000000  0.000000
#
#                                    geneset_size  matched_size  \
# Term
# Hypoxia                                     200           148
# Glycolysis                                  200           164
# TNF-alpha Signaling via NF-kB               200           148
# Epithelial Mesenchymal Transition           200            91
# Estrogen Response Early                     200           171
# Androgen Response                           100            87
# KRAS Signaling Up                           200            83
# UV Response Dn                              144           110
# Apoptosis                                   161           119
# Complement                                  200           115
# Adipogenesis                                200           169
# Fatty Acid Metabolism                       158           125
# Bile Acid Metabolism                        112            69
# Estrogen Response Late                      200           157
# Pperoxisome                                 104            87
# mTORC1 Signaling                            200           192
# Reactive Oxygen Species Pathway              49            43
# UV Response Up                              158           128
# Cholesterol Homeostasis                      74            64
# Xenobiotic Metabolism                       200           128
# Unfolded Protein Response                   113           108
# Spermatogenesis                             135            64
# Mitotic Spindle                             199           188
# DNA Repair                                  150           143
# Myc Targets V2                               58            57
# Myc Targets V1                              200           200
# E2F Targets                                 200           191
# G2-M Checkpoint                             200           187
# Oxidative Phosphorylation                   200           197
#
#                                                                                genes  \
# Term
# Hypoxia                            LDHA;PGK1;ALDOA;GAPDH;ENO1;TPI1;NDRG1;GPI;BNIP...
# Glycolysis                         LDHA;PGK1;ALDOA;ENO1;TPI1;SLC16A3;PKM;SPAG4;P4...
# TNF-alpha Signaling via NF-kB      FOS;PNRC1;BTG1;BHLHE40;EGR1;EIF1;DUSP1;JUN;PDE...
# Epithelial Mesenchymal Transition  PLOD2;ENO2;QSOX1;JUN;LGALS1;MXRA5;EFEMP2;SAT1;...
# Estrogen Response Early            KRT19;KRT18;FOS;KRT8;ELF3;BHLHE40;TOB1;SLC2A1;...
# Androgen Response                  KRT19;NDRG1;KRT8;SCD;H1-0;SPDEF;TPD52;SAT1;PIA...
# KRAS Signaling Up                  ANGPTL4;ERO1A;GPNMB;PPP1R15A;GADD45G;LCP1;PTPR...
# UV Response Dn                     BHLHE40;VLDLR;CDKN1B;CITED2;DUSP1;ATRX;CCN1;AT...
# Apoptosis                          BNIP3L;KRT18;ENO2;CDKN1B;H1-0;JUN;BCL10;TXNIP;...
# Complement                         GATA3;CD55;MAFF;PHEX;XPNPEP1;CD36;RHOG;USP16;U...
# Adipogenesis                       ALDOA;ANGPTL4;UBC;CCNG2;TOB1;VEGFB;GBE1;PIM3;G...
# Fatty Acid Metabolism              LDHA;ALDOA;MIF;ENO2;S100A10;LGALS1;HMGCL;SERIN...
# Bile Acid Metabolism               OPTN;LONP2;ATXN1;ABCA1;NR3C2;SLC22A18;AR;CAT;P...
# Estrogen Response Late             KRT19;FOS;TOB1;DNAJC1;TFF3;CCN5;ZFP36;SNX10;SI...
# Pperoxisome                        DHRS3;PABPC1;BCL10;LONP2;ATXN1;HMGCL;SLC25A4;C...
# mTORC1 Signaling                   LDHA;PGK1;ALDOA;GAPDH;ENO1;TPI1;GPI;P4HA1;ERO1...
# Reactive Oxygen Species Pathway    PFKP;FTL;JUNB;CAT;LAMTOR5;PRDX4;FES;ABCC1;PDLI...
# UV Response Up                     ALDOA;FOS;BTG1;ENO2;PPP1R2;JUNB;NR4A1;TFRC;RHO...
# Cholesterol Homeostasis            ACTG1;PNRC1;SCD;ALDOC;ALCAM;CPEB2;LSS;SREBF2;P...
# Xenobiotic Metabolism              CYB5A;MCCC2;EPHA2;DDT;ACOX3;CD36;DHPS;PMM1;CSA...
# Unfolded Protein Response          ERO1A;EIF4A2;DDIT4;RPS14;NPM1;STC2;CNOT4;KIF5B...
# Spermatogenesis                    CSNK2A2;MLLT10;PIAS2;CHFR;BRAF;SPATA6;IL12RB2;...
# Mitotic Spindle                    EZR;CSNK1D;MYO1E;FLNB;KIF5B;TSC1;CYTH2;AKAP13;...
# DNA Repair                         VPS37B;PDE4B;GUK1;POLD4;RNMT;ERCC5;GTF2H1;ELL;...
# Myc Targets V2                     HK2;NPM1;SLC29A2;WDR74;PES1;DDX18;MYC;MAP3K6;P...
# Myc Targets V1                     LDHA;PGK1;VDAC1;NPM1;RACK1;PABPC1;AP3S1;RPS2;R...
# E2F Targets                        CDKN1B;TFRC;RAD50;PRDX4;HNRNPD;MYC;PPP1R8;ORC2...
# G2-M Checkpoint                    CDKN1B;HOXC10;ATRX;KIF5B;SAP30;NOTCH2;SLC38A1;...
# Oxidative Phosphorylation          LDHA;GPI;VDAC1;CYB5A;ATP5MC2;ABCB7;OPA1;VDAC2;...
#
#                                                                          ledge_genes
# Term
# Hypoxia                            LDHA;PGK1;ALDOA;GAPDH;ENO1;TPI1;NDRG1;GPI;BNIP...
# Glycolysis                         LDHA;PGK1;ALDOA;ENO1;TPI1;SLC16A3;PKM;SPAG4;P4...
# TNF-alpha Signaling via NF-kB      FOS;PNRC1;BTG1;BHLHE40;EGR1;EIF1;DUSP1;JUN;PDE...
# Epithelial Mesenchymal Transition  PLOD2;ENO2;QSOX1;JUN;LGALS1;MXRA5;EFEMP2;SAT1;...
# Estrogen Response Early            KRT19;KRT18;FOS;KRT8;ELF3;BHLHE40;TOB1;SLC2A1;...
# Androgen Response                  KRT19;NDRG1;KRT8;SCD;H1-0;SPDEF;TPD52;SAT1;PIA...
# KRAS Signaling Up                  ANGPTL4;ERO1A;GPNMB;PPP1R15A;GADD45G;LCP1;PTPR...
# UV Response Dn                     BHLHE40;VLDLR;CDKN1B;CITED2;DUSP1;ATRX;CCN1;AT...
# Apoptosis                          LMNA;TNFRSF12A;FDXR;ETF1;TAP1;CDC25B;LGALS3;HM...
# Complement                         ADAM9;KIF2A;GNB2;PRDM4;LGALS3;GCA;CTSC;PPP4C;C...
# Adipogenesis                       CD151;SCP2;SLC5A6;SDHC;CPT2;NMT1;AGPAT3;RNF11;...
# Fatty Acid Metabolism              ACAA1;CPOX;SDHC;EPHX1;CPT2;ACSL1;ETFDH;ALDH9A1...
# Bile Acid Metabolism               PECR;PEX16;DHCR24;PEX19;SLC23A2;FADS2;HACL1;EF...
# Estrogen Response Late             CKB;ABHD2;AFF1;PDLIM3;SLC22A5;NXT1;HMGCS2;ABCA...
# Pperoxisome                        DHCR24;SLC23A2;ERCC3;MVP;HRAS;ACOT8;SEMA3C;IDE...
# mTORC1 Signaling                   ACSL3;GLRX;ADIPOR2;ELOVL6;CTSC;MTHFD2;RPA1;PSM...
# Reactive Oxygen Species Pathway    NDUFA6;HMOX2;SOD2;NDUFS2;TXNRD2;GLRX;GCLM;PRDX...
# UV Response Up                     SOD2;ACAA1;EPCAM;EPHX1;CTSV;EIF5;RPN1;NAT1;TAP...
# Cholesterol Homeostasis            S100A11;HSD17B7;LGALS3;MAL2;PCYT2;PMVK;GPX8;CL...
# Xenobiotic Metabolism              FAH;ACP1;PEMT;NDRG2;CNDP2;NFS1;FAS;IGFBP4;TDO2...
# Unfolded Protein Response          CALR;SLC1A4;SLC30A5;NFYB;EXOSC4;EXOSC1;SRPRB;L...
# Spermatogenesis                    RFC4;HSPA4L;TSN;TOPBP1;NCAPH;BUB1;DBF4;PSMG1;C...
# Mitotic Spindle                    TUBD1;SASS6;PCNT;CAPZB;ARHGEF2;RFC1;FLNA;SMC3;...
# DNA Repair                         NELFCD;RBX1;TAF6;REV3L;BCAM;UMPS;POLH;DAD1;SSR...
# Myc Targets V2                     GNL3;UNG;TBRG4;NDUFAF4;PRMT3;MPHOSPH10;RCL1;RA...
# Myc Targets V1                     CDK2;RRM1;SET;GLO1;EPRS1;XRCC6;SYNCRIP;PPM1G;M...
# E2F Targets                        RFC1;PPM1D;UBR7;GSPT1;IPO7;CDC25B;MRE11;LYAR;S...
# G2-M Checkpoint                    NUP50;CHAF1A;RBL1;BARD1;MTF2;NASP;ILF3;DDX39A;...
# Oxidative Phosphorylation          ACAA1;COX6C;NDUFB3;COX15;SDHC;NDUFA9;COX7A2;AT...

# %%
sc.var_names = sc.var["external_gene_name"].values
scanpy.tl.rank_genes_groups(sc, groupby="leiden", n_genes=len(sc.var_names),rankby_abs=True, method="wilcoxon")

# %%
rnaseq.dea.volcano_plot(sc, group="4", top=50)
