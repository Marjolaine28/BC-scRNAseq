# %%
# %load_ext autoreload
# %autoreload 1
# %autosave 60
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Autosaving every 60 seconds

# %%
import sys
import pandas as pd
import numpy as np
import importlib
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, PowerNorm
import scanpy
import gseapy as gp

# %%
sys.path.append("/u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/")

# %%
import rnaseq
importlib.reload(rnaseq)
# Out:
# <module 'rnaseq' from '/u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/rnaseq/__init__.py'>

# %%
# %%bash
# pwd
# Out:
# /u/davidm/Documents/Master-thesis/Projects/scBC-Analysis/0_Preprocessing/2_Cells-filtering/dsp762

# %%
# %%bash
# tar czf ./figs.tar.gz ./figs/*.pdf

# %% [markdown]
# ### Plotting parameters

# %%
# %matplotlib inline
plt.rcParams['figure.dpi'] = 110
plt.rcParams['font.size'] = 6

# %% [markdown]
# ### Genes lists

# %%
cell_cycle_genes = np.array(['MCM5', 'PCNA', 'TYMS', 'FEN1', 'MCM2', 'MCM4', 'RRM1', 'UNG',
       'GINS2', 'MCM6', 'CDCA7', 'DTL', 'PRIM1', 'UHRF1', 'HELLS', 'RFC2',
       'RPA2', 'NASP', 'RAD51AP1', 'GMNN', 'WDR76', 'SLBP', 'CCNE2',
       'UBR7', 'POLD3', 'MSH2', 'ATAD2', 'RAD51', 'RRM2', 'CDC45', 'CDC6',
       'EXO1', 'TIPIN', 'DSCC1', 'BLM', 'CASP8AP2', 'USP1', 'CLSPN',
       'POLA1', 'CHAF1B', 'BRIP1', 'E2F8', 'HMGB2', 'CDK1', 'NUSAP1',
       'UBE2C', 'BIRC5', 'TPX2', 'TOP2A', 'NDC80', 'CKS2', 'NUF2',
       'CKS1B', 'MKI67', 'TMPO', 'CENPF', 'TACC3', 'SMC4', 'CCNB2',
       'CKAP2L', 'CKAP2', 'AURKB', 'BUB1', 'KIF11', 'ANP32E', 'TUBB4B',
       'GTSE1', 'KIF20B', 'HJURP', 'CDCA3', 'CDC20', 'TTK', 'CDC25C',
       'KIF2C', 'RANGAP1', 'NCAPD2', 'DLGAP5', 'CDCA2', 'CDCA8', 'ECT2',
       'KIF23', 'HMMR', 'AURKA', 'PSRC1', 'ANLN', 'LBR', 'CKAP5', 'CENPE',
       'CTCF', 'NEK2', 'G2E3', 'GAS2L3', 'CBX5', 'CENPA'])

s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]

# %%
g2m_genes = ['ABL1', 'AMD1', 'ARID4A', 'ATF5', 'ATRX', 'AURKA', 'AURKB',
       'BARD1', 'BCL3', 'BIRC5', 'BRCA2', 'BUB1', 'BUB3', 'CASP8AP2',
       'CBX1', 'CCNA2', 'CCNB2', 'CCND1', 'CCNF', 'CCNT1', 'CDC20',
       'CDC25A', 'CDC25B', 'CDC27', 'CDC45', 'CDC6', 'CDC7', 'CDK1',
       'CDK4', 'CDKN1B', 'CDKN2C', 'CDKN3', 'CENPA', 'CENPE', 'CENPF',
       'CHAF1A', 'CHEK1', 'CHMP1A', 'CKS1B', 'CKS2', 'CTCF', 'CUL1',
       'CUL3', 'CUL4A', 'CUL5', 'DBF4', 'DDX39A', 'DKC1', 'DMD', 'DR1',
       'DTYMK', 'E2F1', 'E2F2', 'E2F3', 'E2F4', 'EFNA5', 'EGF', 'ESPL1',
       'EWSR1', 'EXO1', 'EZH2', 'FANCC', 'FBXO5', 'FOXN3', 'G3BP1',
       'GINS2', 'GSPT1', 'H2AX', 'H2AZ1', 'H2AZ2', 'H2BC12', 'HIF1A',
       'HIRA', 'HMGA1', 'HMGB3', 'HMGN2', 'HMMR', 'HNRNPD', 'HNRNPU',
       'HOXC10', 'HSPA8', 'HUS1', 'ILF3', 'INCENP', 'JPT1', 'KATNA1',
       'KIF11', 'KIF15', 'KIF20B', 'KIF22', 'KIF23', 'KIF2C', 'KIF4A',
       'KIF5B', 'KMT5A', 'KNL1', 'KPNA2', 'KPNB1', 'LBR', 'LIG3', 'LMNB1',
       'MAD2L1', 'MAP3K20', 'MAPK14', 'MARCKS', 'MCM2', 'MCM3', 'MCM5',
       'MCM6', 'MEIS1', 'MEIS2', 'MKI67', 'MNAT1', 'MT2A', 'MTF2',
       'MYBL2', 'MYC', 'NASP', 'NCL', 'NDC80', 'NEK2', 'NOLC1', 'NOTCH2',
       'NSD2', 'NUMA1', 'NUP50', 'NUP98', 'NUSAP1', 'ODC1', 'ODF2',
       'ORC5', 'ORC6', 'PAFAH1B1', 'PBK', 'PDS5B', 'PLK1', 'PLK4', 'PML',
       'POLA2', 'POLE', 'POLQ', 'PRC1', 'PRIM2', 'PRMT5', 'PRPF4B',
       'PTTG1', 'PTTG3P', 'PURA', 'RACGAP1', 'RAD21', 'RAD23B', 'RAD54L',
       'RASAL2', 'RBL1', 'RBM14', 'RPA2', 'RPS6KA5', 'SAP30', 'SFPQ',
       'SLC12A2', 'SLC38A1', 'SLC7A1', 'SLC7A5', 'SMAD3', 'SMARCC1',
       'SMC1A', 'SMC2', 'SMC4', 'SNRPD1', 'SQLE', 'SRSF1', 'SRSF10',
       'SRSF2', 'SS18', 'STAG1', 'STIL', 'STMN1', 'SUV39H1', 'SYNCRIP',
       'TACC3', 'TENT4A', 'TFDP1', 'TGFB1', 'TLE3', 'TMPO', 'TNPO2',
       'TOP1', 'TOP2A', 'TPX2', 'TRA2B', 'TRAIP', 'TROAP', 'TTK', 'UBE2C',
       'UBE2S', 'UCK2', 'UPF1', 'WRN', 'XPO1', 'YTHDC1']

# %% [markdown]
# ### Load sample

# %%
sample = "Sample_T47D"
new_sample_name = "T47D"
quant_params = "trimmed-reads-cutadapt-all/decoys-k19-1.4.0/customWh-top-3000"
genref = "human/assembly__GRCh38-hg38/annotation__gencode/gencode_34"
project = "dsp762"
cell_line = "T47D"

# %%
sc = rnaseq.readwrite.read_raw(project_id  = project, quant_tool = "alevin", samples = sample, genes_id = "ensembl_gene_id", quant_params = quant_params, genref = genref, cdna = "3' tag", exp = "sc")
sc.obs_names = sc.obs["CB"].tolist()
# Out:
# /home/arion/davidm/Data/datasets/raw/private/RNA-seq/sc/dsp762/quant/alevin/human/assembly__GRCh38-hg38/annotation__gencode/gencode_34/trimmed-reads-cutadapt-all/decoys-k19-1.4.0/customWh-top-3000
# Using BioMart Ensembl Genes 100 hsapiens_gene_ensembl for gene annotations.

# %%
rnaseq.setup.annotate_samples(sc, samples_annot_name = "samples", samples_annot = new_sample_name, ow = True)
rnaseq.setup.annotate_samples(sc, samples_annot_name = "cell_line", samples_annot = cell_line, ow = True)

rnaseq.setup.annotate_samples(sc, samples_annot_name = "total_UMIs", samples_annot = sc.X.toarray().sum(1).ravel())
rnaseq.setup.annotate_samples(sc, samples_annot_name = "#_genes", samples_annot = (sc.X.toarray() != 0).sum(1).ravel())
rnaseq.setup.annotate_samples(sc, samples_annot_name = "max_corr")
rnaseq.setup.annotate_samples(sc, samples_annot_name = "mt_frac")
rnaseq.setup.annotate_samples(sc, samples_annot_name = "rp_frac")

rnaseq.setup.annotate_genes(sc, "gene_biotype")
# Out:
# Annotating samples...
# Annotating cell_line...
# Annotating total_UMIs...
# Annotating #_genes...
# Annotating max_corr...
# Normalization by total UMIs...
# Log2 + 1 tranformation...
# Annotating mt_frac...
# Annotating chromosome_name using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...
# Annotating rp_frac...
# Annotating external_gene_name using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...
# Annotating gene_biotype using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...

# %%
sc._inplace_subset_obs(sc.obs["total_UMIs"] > 100)

# %%
sc.X.shape
# Out:
# (2399, 60240)

# %%
# x = sc.layers["raw"].toarray()[:, (sc.var["gene_biotype"] == "lncRNA") & (sc.var["external_gene_name"] != "MALAT1")]
x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "lncRNA"]
sc.obs["lncRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "rRNA"]
sc.obs["rRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "Mt_rRNA"]
sc.obs["Mt_rRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "protein_coding"]
sc.obs["protein_coding"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "processed_pseudogene"]
sc.obs["processed_pseudogene"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, [g.startswith("HSP") for g in sc.var["external_gene_name"]]]
sc.obs["hsp_frac"] = x.sum(1) / sc.obs["total_UMIs"]

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)

sc.var_names = sc.var["external_gene_name"].values
sc.var_names = np.array(sc.var_names.values)
sc.var_names_make_unique()
scanpy.tl.score_genes_cell_cycle(sc, s_genes=s_genes, g2m_genes=g2m_genes)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc_copy = sc.copy()

# %% [markdown]
# ### QC distributions

# %%
sc = sc_copy.copy()

# %%
plt.boxplot(sc.obs["total_UMIs"]);

# %%
_,ax = plt.subplots(figsize=(2.5,2))
rnaseq.plotting.loghist(sc.obs["total_UMIs"], bins=20, ax=ax, linewidth=0.1, edgecolor='black', fc = "white");
# ax.set_xlim(200,25000)
plt.axvline(2000, linewidth = 0.8, c = 'red')
plt.title(new_sample_name)
plt.ylabel("Fréquence")
plt.xlabel("Nombre de UMI")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Nombre de UMI')

# %%
_,ax = plt.subplots(figsize=(2.5,2))
plt.hist(sc.obs["max_corr"], bins=20, linewidth=0.1, edgecolor='black', fc = "white");
plt.title(new_sample_name)
plt.axvline(0.7, linewidth = 0.8, c = 'red')
plt.ylabel("Fréquence")
plt.xlabel("Rmax")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Rmax')

# %%
_,ax = plt.subplots(figsize=(2.5,2))
plt.hist(sc.obs["Mt_rRNA"], bins=20, linewidth=0.1, edgecolor='black', fc = "white");
plt.title(new_sample_name)
plt.axvline(0.03, linewidth = 0.8, c = 'red')
plt.ylabel("Fréquence")
plt.xlabel("Fraction de Mt_rRNA")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Fraction de Mt_rRNA')

# %% [markdown]
# ### Explore sample

# %%
sc = sc_copy.copy()

# %%
metrics = ['total_UMIs', '#_genes', 'max_corr', 'MappingRate','DedupRate', 'mt_frac', 'rp_frac']
powers_metrics = [0.1,0.3,0.8,1.3,1.5,0.5,1.2]

biotypes = ['rRNA', 'Mt_rRNA', 'lncRNA', 'processed_pseudogene', 'protein_coding', 'G2M_score', 'hsp_frac', 'marker']
powers_biotypes = [1,0.5,0.5,0.5,1.8,0.5, 0.5, 1]

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)
scanpy.pp.pca(sc, n_comps=50)
scanpy.pp.neighbors(sc, n_pcs=20, n_neighbors=15)
scanpy.tl.umap(sc, n_components=2)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc.obs["marker"] = sc.X.toarray()[:, sc.var["external_gene_name"].values == "ALDOA"] # HSPA5 SERP1

# %%
scatt = plt.subplots(figsize=(10,2.5), sharey=True)
for i,(c,p) in enumerate(zip(biotypes,powers_biotypes)):
    axi = plt.subplot(2,9,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 2, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(biotypes):
    axi = plt.subplot(2,9,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    plt.hist(sc.obs[c],  bins = 20, color="white", edgecolor="gray", linewidth = 0.3);

# %%
scatt = plt.subplots(figsize=(9.5,2.5), sharey=True)
for i,(c,p) in enumerate(zip(metrics,powers_metrics)):
    axi = plt.subplot(2,8,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 1.5, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(metrics):
    axi = plt.subplot(2,8,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    if c in ["total_UMIs", "#_genes"] :
        rnaseq.plotting.loghist(sc.obs[c], bins=20, ax=axi, linewidth=0.3, color="white", edgecolor="gray");
    else :
        plt.hist(sc.obs[c],  bins = 15, color="white", edgecolor="gray", linewidth = 0.3);

# %% [markdown]
# ### Filter sample

# %%
sc = sc_copy.copy()

# %%
sc._inplace_subset_obs(sc.obs["total_UMIs"] > 1000)
# sc._inplace_subset_obs(sc.obs["Mt_rRNA"] < 0.05)
sc._inplace_subset_obs(sc.obs["Mt_rRNA"] < 0.07)
# sc._inplace_subset_obs(sc.obs["lncRNA"] < 0.05)

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)
scanpy.pp.pca(sc, n_comps=50)
scanpy.pp.neighbors(sc, n_pcs=20, n_neighbors=15)
scanpy.tl.umap(sc, n_components=2)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc.obs["marker"] = sc.X.toarray()[:, sc.var["external_gene_name"].values == "ALDOA"] # HSPA5 SERP1

# %%
scatt = plt.subplots(figsize=(10,2.5), sharey=True)
for i,(c,p) in enumerate(zip(biotypes,powers_biotypes)):
    axi = plt.subplot(2,9,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 2, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(biotypes):
    axi = plt.subplot(2,9,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    plt.hist(sc.obs[c],  bins = 20, color="white", edgecolor="gray", linewidth = 0.3);

# %%
scatt = plt.subplots(figsize=(9.5,2.5), sharey=True)
for i,(c,p) in enumerate(zip(metrics,powers_metrics)):
    axi = plt.subplot(2,8,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 1.5, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(metrics):
    axi = plt.subplot(2,8,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    if c in ["total_UMIs", "#_genes"] :
        rnaseq.plotting.loghist(sc.obs[c], bins=20, ax=axi, linewidth=0.3, color="white", edgecolor="gray");
    else :
        plt.hist(sc.obs[c],  bins = 15, color="white", edgecolor="gray", linewidth = 0.3);

# %%
sc.X.shape
# Out:
# (1425, 60240)

# %% [markdown]
# ### Save filtered data

# %%
rnaseq.readwrite.write_filtered(sc)
# Out:
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'samples' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'project_id' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cell_line' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'phase' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromosome_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'external_gene_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_biotype' as categorical

# %%
del sc, sc_copy

# %% [markdown]
# ### Heterogeneity analysis

# %%
scanpy.tl.leiden(sc, resolution=0.25)

scatt,_ = plt.subplots(figsize=(3,2))

rnaseq.plotting.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], color = sc.obs["leiden"], \
    s = 20, xlabel="UMAP1", ylabel="UMAP2", color_title = "clusters",\
    title = new_sample_name, linewidth=0.15, fig = scatt)

# %%
rnaseq.setup.annotate_genes(sc, 'description')
# Out:
# Annotating description using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...

# %%
gene_exp = pd.DataFrame(sc.X.toarray().T, columns = sc.obs["CB"].values)
class_vector = (sc.obs["leiden"].values == '1').astype(str)
class_vector = np.where(class_vector == 'True', "cluster", class_vector) 
class_vector = np.where(class_vector == 'False', "rest", class_vector)

# %%
idx = np.argsort(class_vector)
gene_exp = gene_exp[gene_exp.columns[idx]]
gene_exp.insert(0, "DESCRIPTION", sc.var["description"].values, True)
gene_exp.insert(0, "NAME", sc.var["external_gene_name"].values, True)

class_vector = list(class_vector[idx])

# %%
gs_res = gp.gsea(gene_exp, # ordata='./P53_resampling_data.txt'
                 'MSigDB_Hallmark_2020', # enrichr library names
                  class_vector,
                 # set permutation_type to phenotype if samples >=15
                 permutation_type='phenotype',
                 permutation_num=100, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 method='signal_to_noise',
                 processes=4, seed= 7,
                 format='png')
# Out:
# 2021-12-15 13:35:26,054 Warning: dropping duplicated gene names, only keep the first values

# %%
res = gs_res.res2d.sort_values(by='nes', ascending=False)
res = res.loc[res.index[(res['fdr'].values < 0.05) & (res['pval'].values < 0.05)]]

# %%
res #3
# Out:
#                                  es       nes  pval       fdr  geneset_size  \
# Term
# mTORC1 Signaling           0.405330  2.071132   0.0  0.000000           200
# Myc Targets V1             0.430562  1.901059   0.0  0.024590           200
# Oxidative Phosphorylation  0.386347  1.842516   0.0  0.032787           200
#
#                            matched_size  \
# Term
# mTORC1 Signaling                    185
# Myc Targets V1                      199
# Oxidative Phosphorylation           195
#
#                                                                        genes  \
# Term
# mTORC1 Signaling           GAPDH;ALDOA;PGK1;TPI1;PSMA4;ENO1;LDHA;PPA1;P4H...
# Myc Targets V1             RPS2;RPLP0;HSP90AB1;VDAC1;PGK1;CCT2;PSMA4;UBE2...
# Oxidative Phosphorylation  ATP5PB;VDAC1;NDUFB4;LDHA;NDUFC2;MDH1;HSPA9;ATP...
#
#                                                                  ledge_genes
# Term
# mTORC1 Signaling           GAPDH;ALDOA;PGK1;TPI1;PSMA4;ENO1;LDHA;PPA1;P4H...
# Myc Targets V1             RPS2;RPLP0;HSP90AB1;VDAC1;PGK1;CCT2;PSMA4;UBE2...
# Oxidative Phosphorylation  ATP5PB;VDAC1;NDUFB4;LDHA;NDUFC2;MDH1;HSPA9;ATP...

# %%
res #2
# Out:
#                                          es       nes  pval       fdr  \
# Term
# G2-M Checkpoint                    0.762332  3.504956   0.0  0.000000
# E2F Targets                        0.822970  3.418099   0.0  0.000000
# Myc Targets V1                     0.727158  3.307865   0.0  0.000000
# mTORC1 Signaling                   0.593327  3.042414   0.0  0.000000
# DNA Repair                         0.600198  3.029228   0.0  0.000000
# Mitotic Spindle                    0.544437  2.900710   0.0  0.000000
# UV Response Up                     0.583937  2.805621   0.0  0.000000
# Myc Targets V2                     0.674641  2.778889   0.0  0.000000
# Unfolded Protein Response          0.596042  2.754284   0.0  0.000000
# Estrogen Response Late             0.500776  2.734815   0.0  0.000000
# Spermatogenesis                    0.559178  2.681902   0.0  0.000000
# Apoptosis                          0.489974  2.649739   0.0  0.000000
# p53 Pathway                        0.463921  2.535453   0.0  0.000000
# Oxidative Phosphorylation          0.540359  2.525983   0.0  0.000000
# Reactive Oxygen Species Pathway    0.566720  2.365535   0.0  0.000000
# Fatty Acid Metabolism              0.481764  2.334845   0.0  0.000000
# heme Metabolism                    0.434554  2.301253   0.0  0.000000
# Glycolysis                         0.437213  2.269871   0.0  0.000000
# Xenobiotic Metabolism              0.474295  2.261853   0.0  0.000000
# Allograft Rejection                0.442210  2.249889   0.0  0.000000
# Adipogenesis                       0.454894  2.221692   0.0  0.000000
# PI3K/AKT/mTOR  Signaling           0.510892  2.218374   0.0  0.000000
# Inflammatory Response              0.405572  2.167246   0.0  0.000000
# Pperoxisome                        0.464980  2.139447   0.0  0.000000
# Interferon Gamma Response          0.383542  2.086024   0.0  0.000000
# Androgen Response                  0.437700  2.067828   0.0  0.000000
# Cholesterol Homeostasis            0.478655  2.049000   0.0  0.000000
# Apical Junction                    0.402046  2.046770   0.0  0.000000
# Myogenesis                         0.418554  2.023338   0.0  0.000000
# Interferon Alpha Response          0.385712  2.008330   0.0  0.001562
# Hypoxia                            0.364961  1.993681   0.0  0.001511
# Epithelial Mesenchymal Transition  0.413173  1.979667   0.0  0.001464
# Complement                         0.397514  1.971445   0.0  0.001420
# Estrogen Response Early            0.341668  1.940230   0.0  0.001378
# Protein Secretion                  0.450721  1.916747   0.0  0.001338
# TNF-alpha Signaling via NF-kB      0.322981  1.778060   0.0  0.001301
# Bile Acid Metabolism               0.374646  1.726502   0.0  0.001266
# IL-2/STAT5 Signaling               0.361332  1.720536   0.0  0.001233
# KRAS Signaling Up                  0.330285  1.575096   0.0  0.013213
# UV Response Dn                     0.323014  1.542455   0.0  0.018738
# Coagulation                        0.312345  1.514852   0.0  0.024538
#
#                                    geneset_size  matched_size  \
# Term
# G2-M Checkpoint                             200           199
# E2F Targets                                 200           200
# Myc Targets V1                              200           200
# mTORC1 Signaling                            200           193
# DNA Repair                                  150           144
# Mitotic Spindle                             199           193
# UV Response Up                              158           129
# Myc Targets V2                               58            58
# Unfolded Protein Response                   113           109
# Estrogen Response Late                      200           167
# Spermatogenesis                             135            68
# Apoptosis                                   161           119
# p53 Pathway                                 200           182
# Oxidative Phosphorylation                   200           197
# Reactive Oxygen Species Pathway              49            42
# Fatty Acid Metabolism                       158           126
# heme Metabolism                             200           155
# Glycolysis                                  200           166
# Xenobiotic Metabolism                       200           133
# Allograft Rejection                         200            89
# Adipogenesis                                200           170
# PI3K/AKT/mTOR  Signaling                    105            90
# Inflammatory Response                       200            92
# Pperoxisome                                 104            83
# Interferon Gamma Response                   200           132
# Androgen Response                           100            91
# Cholesterol Homeostasis                      74            64
# Apical Junction                             200           128
# Myogenesis                                  200           113
# Interferon Alpha Response                    97            73
# Hypoxia                                     200           146
# Epithelial Mesenchymal Transition           200            93
# Complement                                  200           123
# Estrogen Response Early                     200           178
# Protein Secretion                            96            92
# TNF-alpha Signaling via NF-kB               200           151
# Bile Acid Metabolism                        112            70
# IL-2/STAT5 Signaling                        199           139
# KRAS Signaling Up                           200            96
# UV Response Dn                              144           117
# Coagulation                                 138            63
#
#                                                                                genes  \
# Term
# G2-M Checkpoint                    CDK1;TOP2A;EXO1;EZH2;MKI67;NOLC1;SMC4;CDC6;NCL...
# E2F Targets                        RRM2;HMGB2;ATAD2;DUT;CDK1;PCNA;DEK;HELLS;TOP2A...
# Myc Targets V1                     DUT;PCNA;DEK;USP1;MCM7;NOLC1;MCM4;NOP56;SERBP1...
# mTORC1 Signaling                   RRM2;MCM4;DHFR;UNG;TMEM97;EIF2S2;MCM2;CDKN1A;C...
# DNA Repair                         DUT;PCNA;ZWINT;FEN1;RFC3;RFC4;TYMS;PRIM1;RFC2;...
# Mitotic Spindle                    CDK1;TOP2A;SMC4;SMC3;PRC1;NDC80;ANLN;LMNB1;KIF...
# UV Response Up                     H2AX;FEN1;RFC4;PARP2;DDX21;BTG3;TFRC;TUBA4A;EI...
# Myc Targets V2                     NOLC1;MCM4;NOP56;TCOF1;PA2G4;UNG;TMEM97;DCTPP1...
# Unfolded Protein Response          NOLC1;NOP56;FUS;EIF4A1;H2AX;DKC1;CKS1B;EIF4EBP...
# Estrogen Response Late             TOP2A;CDC6;RBBP8;GINS2;IL17RB;BTG3;SFN;RNASEH2...
# Spermatogenesis                    CDK1;EZH2;RFC4;PARP2;KIF2C;VDAC3;TOPBP1;DBF4;Z...
# Apoptosis                          HMGB2;TOP2A;BRCA1;CDKN1A;BTG3;SLC20A1;EBP;H1-0...
# p53 Pathway                        PCNA;CDKN1A;JAG2;RAD51C;SFN;SPHK1;IER5;PPM1D;M...
# Oxidative Phosphorylation          VDAC3;FH;AFG3L2;HSPA9;LRPPRC;NDUFS8;OXA1L;CS;N...
# Reactive Oxygen Species Pathway    CDKN2D;EGLN2;PFKP;SELENOS;GPX4;GLRX2;STK25;GCL...
# Fatty Acid Metabolism              YWHAH;APEX1;FH;H2AZ1;NCAPH2;GPD2;ERP29;KMT5A;D...
# heme Metabolism                    H4C3;E2F2;GMPS;UBAC1;SLC25A37;TFRC;H1-0;MFHAS1...
# Glycolysis                         CDK1;STMN1;NASP;POLR3K;AK4;PGAM1;SLC16A3;SLC25...
# Xenobiotic Metabolism              TMEM97;KARS1;ATP2A2;MTHFD1;GART;SHMT2;PTGES3;A...
# Allograft Rejection                BRCA1;AKT1;ABCE1;NPM1;EIF5A;EIF3J;FLNA;CDKN2A;...
# Adipogenesis                       GPAT4;SLC25A10;AK2;GPD2;TKT;CMPK1;CS;PLIN2;RTN...
# PI3K/AKT/mTOR  Signaling           CDK1;CDKN1A;PPP1CA;AKT1;SFN;CDK4;GRB2;E2F1;SQS...
# Inflammatory Response              CDKN1A;ATP2A2;SPHK1;ADRM1;ATP2B1;GCH1;SELENOS;...
# Pperoxisome                        TOP2A;YWHAH;MSH2;SLC25A19;SMARCC1;ISOC1;PABPC1...
# Interferon Gamma Response          CDKN1A;PNP;SLC25A28;ISOC1;PFKP;PSMA3;CASP3;GCH...
# Androgen Response                  PA2G4;UBE2I;AKT1;XRCC6;H1-0;ADRM1;XRCC5;ACTN1;...
# Cholesterol Homeostasis            TMEM97;ANXA5;EBP;SQLE;TNFRSF12A;GUSB;ACTG1;ATF...
# Apical Junction                    YWHAH;IKBKG;ACTG1;TUBG1;ACTN1;ITGB1;PLCG1;EVL;...
# Myogenesis                         TPM3;CDKN1A;SPHK1;CKB;ITGB1;IFRD1;MYO1C;TNNT1;...
# Interferon Alpha Response          SLC25A28;PSMA3;PSME1;PSME2;LAP3;OGFR;NUB1;LY6E...
# Hypoxia                            CDKN1A;AK4;PFKP;ATF3;PLIN2;GPI;TPI1;ENO1;RBPJ;...
# Epithelial Mesenchymal Transition  MCM7;COLGALT1;CALU;TNFRSF12A;ITGB1;FLNA;PPIB;R...
# Complement                         ANXA5;GRB2;GPD2;KIF2A;CASP3;RABIF;HSPA1A;PFN1;...
# Estrogen Response Early            RBBP8;IL17RB;SFN;MUC1;ADCY1;PPIF;ARL3;OLFM1;IS...
# Protein Secretion                  ATP1A1;ANP32E;TMX1;CD63;GOLGA4;AP2S1;LMAN1;GNA...
# TNF-alpha Signaling via NF-kB      PHLDA2;CDKN1A;BTG3;SPHK1;IER5;NFE2L2;ATP2B1;SQ...
# Bile Acid Metabolism               ISOC1;DHCR24;SLC35B2;GCLM;ABCA3;SLC27A5;PRDX5;...
# IL-2/STAT5 Signaling               CDC6;MUC1;PNP;PHTF2;UCK2;CASP3;PLIN2;CCNE1;GPX...
# KRAS Signaling Up                  WDR33;TSPAN13;MMD;TOR1AIP2;DCBLD2;USP12;ANO1;S...
# UV Response Dn                     ATP2B1;AGGF1;NFIB;TENT4A;ATRX;SLC7A1;AMPH;SYNJ...
# Coagulation                        CRIP2;RABIF;RAC1;WDR1;GNB2;PEF1;THBS1;F12;CFD;...
#
#                                                                          ledge_genes
# Term
# G2-M Checkpoint                    CDK1;TOP2A;EXO1;EZH2;MKI67;NOLC1;SMC4;CDC6;NCL...
# E2F Targets                        RRM2;HMGB2;ATAD2;DUT;CDK1;PCNA;DEK;HELLS;TOP2A...
# Myc Targets V1                     DUT;PCNA;DEK;USP1;MCM7;NOLC1;MCM4;NOP56;SERBP1...
# mTORC1 Signaling                   RRM2;MCM4;DHFR;UNG;TMEM97;EIF2S2;MCM2;CDKN1A;C...
# DNA Repair                         DUT;PCNA;ZWINT;FEN1;RFC3;RFC4;TYMS;PRIM1;RFC2;...
# Mitotic Spindle                    CDK1;TOP2A;SMC4;SMC3;PRC1;NDC80;ANLN;LMNB1;KIF...
# UV Response Up                     H2AX;FEN1;RFC4;PARP2;DDX21;BTG3;TFRC;TUBA4A;EI...
# Myc Targets V2                     NOLC1;MCM4;NOP56;TCOF1;PA2G4;UNG;TMEM97;DCTPP1...
# Unfolded Protein Response          NOLC1;NOP56;FUS;EIF4A1;H2AX;DKC1;CKS1B;EIF4EBP...
# Estrogen Response Late             TOP2A;CDC6;RBBP8;GINS2;IL17RB;BTG3;SFN;RNASEH2...
# Spermatogenesis                    CDK1;EZH2;RFC4;PARP2;KIF2C;VDAC3;TOPBP1;DBF4;Z...
# Apoptosis                          HMGB2;TOP2A;BRCA1;CDKN1A;BTG3;SLC20A1;EBP;H1-0...
# p53 Pathway                        PCNA;CDKN1A;JAG2;RAD51C;SFN;SPHK1;IER5;PPM1D;M...
# Oxidative Phosphorylation          VDAC3;FH;AFG3L2;HSPA9;LRPPRC;NDUFS8;OXA1L;CS;N...
# Reactive Oxygen Species Pathway    CDKN2D;EGLN2;PFKP;SELENOS;GPX4;GLRX2;STK25;GCL...
# Fatty Acid Metabolism              YWHAH;APEX1;FH;H2AZ1;NCAPH2;GPD2;ERP29;KMT5A;D...
# heme Metabolism                    H4C3;E2F2;GMPS;UBAC1;SLC25A37;TFRC;H1-0;MFHAS1...
# Glycolysis                         CDK1;STMN1;NASP;POLR3K;AK4;PGAM1;SLC16A3;SLC25...
# Xenobiotic Metabolism              TMEM97;KARS1;ATP2A2;MTHFD1;GART;SHMT2;PTGES3;A...
# Allograft Rejection                BRCA1;AKT1;ABCE1;NPM1;EIF5A;EIF3J;FLNA;CDKN2A;...
# Adipogenesis                       GPAT4;SLC25A10;AK2;GPD2;TKT;CMPK1;CS;PLIN2;RTN...
# PI3K/AKT/mTOR  Signaling           CDK1;CDKN1A;PPP1CA;AKT1;SFN;CDK4;GRB2;E2F1;SQS...
# Inflammatory Response              CDKN1A;ATP2A2;SPHK1;ADRM1;ATP2B1;GCH1;SELENOS;...
# Pperoxisome                        TOP2A;YWHAH;MSH2;SLC25A19;SMARCC1;ISOC1;PABPC1...
# Interferon Gamma Response          CDKN1A;PNP;SLC25A28;ISOC1;PFKP;PSMA3;CASP3;GCH...
# Androgen Response                  PA2G4;UBE2I;AKT1;XRCC6;H1-0;ADRM1;XRCC5;ACTN1;...
# Cholesterol Homeostasis            TMEM97;ANXA5;EBP;SQLE;TNFRSF12A;GUSB;ACTG1;ATF...
# Apical Junction                    YWHAH;IKBKG;ACTG1;TUBG1;ACTN1;ITGB1;PLCG1;EVL;...
# Myogenesis                         TPM3;CDKN1A;SPHK1;CKB;ITGB1;IFRD1;MYO1C;TNNT1;...
# Interferon Alpha Response          SLC25A28;PSMA3;PSME1;PSME2;LAP3;OGFR;NUB1;LY6E...
# Hypoxia                            CDKN1A;AK4;PFKP;ATF3;PLIN2;GPI;TPI1;ENO1;RBPJ;...
# Epithelial Mesenchymal Transition  MCM7;COLGALT1;CALU;TNFRSF12A;ITGB1;FLNA;PPIB;R...
# Complement                         ANXA5;GRB2;GPD2;KIF2A;CASP3;RABIF;HSPA1A;PFN1;...
# Estrogen Response Early            RBBP8;IL17RB;SFN;MUC1;ADCY1;PPIF;ARL3;OLFM1;IS...
# Protein Secretion                  ATP1A1;ANP32E;TMX1;CD63;GOLGA4;AP2S1;LMAN1;GNA...
# TNF-alpha Signaling via NF-kB      PHLDA2;CDKN1A;BTG3;SPHK1;IER5;NFE2L2;ATP2B1;SQ...
# Bile Acid Metabolism               ISOC1;DHCR24;SLC35B2;GCLM;ABCA3;SLC27A5;PRDX5;...
# IL-2/STAT5 Signaling               CDC6;MUC1;PNP;PHTF2;UCK2;CASP3;PLIN2;CCNE1;GPX...
# KRAS Signaling Up                  WDR33;TSPAN13;MMD;TOR1AIP2;DCBLD2;USP12;ANO1;S...
# UV Response Dn                     ATP2B1;AGGF1;NFIB;TENT4A;ATRX;SLC7A1;AMPH;SYNJ...
# Coagulation                        CRIP2;RABIF;RAC1;WDR1;GNB2;PEF1;THBS1;F12;CFD;...

# %%
res #1
# Out:
#                                  es       nes      pval       fdr  \
# Term
# Mitotic Spindle            0.592153  2.963597  0.000000  0.000000
# G2-M Checkpoint            0.647797  2.824490  0.000000  0.000000
# Protein Secretion          0.578054  2.598692  0.000000  0.000000
# Unfolded Protein Response  0.516985  2.566880  0.000000  0.000000
# Myc Targets V1             0.628941  2.464674  0.000000  0.000000
# TGF-beta Signaling         0.554614  2.401786  0.000000  0.000000
# mTORC1 Signaling           0.483399  2.371473  0.000000  0.000000
# E2F Targets                0.574390  2.368703  0.000000  0.000000
# Spermatogenesis            0.495528  2.173622  0.000000  0.000000
# Androgen Response          0.432617  2.047265  0.000000  0.000000
# Myc Targets V2             0.495106  1.897471  0.035714  0.003668
# Apoptosis                  0.406086  1.897170  0.000000  0.003363
# DNA Repair                 0.404758  1.819706  0.000000  0.009312
# Apical Junction            0.347558  1.811621  0.000000  0.008647
# PI3K/AKT/mTOR  Signaling   0.397689  1.810500  0.000000  0.008070
# heme Metabolism            0.355586  1.807541  0.000000  0.007566
# Glycolysis                 0.369651  1.805363  0.000000  0.007121
# UV Response Up             0.357422  1.764385  0.000000  0.015692
# Fatty Acid Metabolism      0.372695  1.747419  0.000000  0.016990
# Oxidative Phosphorylation  0.392871  1.710533  0.030303  0.016140
# p53 Pathway                0.312262  1.621306  0.000000  0.028822
# Estrogen Response Late     0.304628  1.619444  0.000000  0.029346
# Xenobiotic Metabolism      0.318684  1.584250  0.000000  0.033333
# IL-6/JAK/STAT3 Signaling   0.364121  1.582896  0.000000  0.031944
# Allograft Rejection        0.340937  1.560037  0.000000  0.035509
#
#                            geneset_size  matched_size  \
# Term
# Mitotic Spindle                     199           192
# G2-M Checkpoint                     200           200
# Protein Secretion                    96            92
# Unfolded Protein Response           113           110
# Myc Targets V1                      200           200
# TGF-beta Signaling                   54            48
# mTORC1 Signaling                    200           194
# E2F Targets                         200           200
# Spermatogenesis                     135            70
# Androgen Response                   100            90
# Myc Targets V2                       58            58
# Apoptosis                           161           123
# DNA Repair                          150           144
# Apical Junction                     200           129
# PI3K/AKT/mTOR  Signaling            105            89
# heme Metabolism                     200           158
# Glycolysis                          200           166
# UV Response Up                      158           129
# Fatty Acid Metabolism               158           126
# Oxidative Phosphorylation           200           197
# p53 Pathway                         200           181
# Estrogen Response Late              200           170
# Xenobiotic Metabolism               200           134
# IL-6/JAK/STAT3 Signaling             87            47
# Allograft Rejection                 200            89
#
#                                                                        genes  \
# Term
# Mitotic Spindle            CENPE;NEK2;CENPF;DLGAP5;CCNB2;BIRC5;PLK1;KIF20...
# G2-M Checkpoint            PTTG1;CKS2;CENPE;NEK2;UBE2S;CENPF;HMMR;CCNB2;B...
# Protein Secretion          ANP32E;ARF1;ARFGEF1;ATP1A1;CLTC;VPS4B;SCRN1;IG...
# Unfolded Protein Response  HSP90B1;KIF5B;HSPA5;CKS1B;YWHAZ;PAIP1;EIF4G1;T...
# Myc Targets V1             HSP90AB1;CDC20;KPNA2;HNRNPA1;HNRNPA3;GSPT1;CBX...
# TGF-beta Signaling         ARID4B;ID3;ID1;PPP1CA;SKIL;CTNNB1;RHOA;SPTBN1;...
# mTORC1 Signaling           HSP90B1;PLK1;AURKA;HSPD1;HSPA5;BUB1;STIP1;PSMC...
# E2F Targets                PTTG1;CKS2;CENPE;UBE2S;DLGAP5;HMMR;CCNB2;BIRC5...
# Spermatogenesis            NEK2;CCNB2;CDKN3;AURKA;BUB1;STRBP;KIF2C;PRKAR2...
# Androgen Response          PA2G4;XRCC6;LMAN1;MYL12A;SPDEF;GNAI3;DHCR24;SM...
# Myc Targets V2             PLK1;CBX3;HSPD1;HSPE1;DDX18;PA2G4;FARSA;LAS1L;...
# Apoptosis                  LMNA;DNAJA1;CDC25B;CREBBP;PDCD4;IGF2R;RARA;PPT...
# DNA Repair                 ARL6IP1;POLR3GL;ERCC5;COX17;ZWINT;RALA;POLR2A;...
# Apical Junction            NECTIN2;CAP1;ACTN4;ITGA2;CTNNA1;CRB3;PPP2R2C;S...
# PI3K/AKT/mTOR  Signaling   HSP90B1;ARF1;PPP1CA;ARHGDIA;CLTC;ACTR2;PTPN11;...
# heme Metabolism            TOP1;HDGF;CAST;GLRX5;GDE1;XPO7;RAD23A;PSMD9;NU...
# Glycolysis                 HMMR;AURKA;KIF20A;HSPA5;STMN1;FKBP4;DEPDC1;RAR...
# UV Response Up             DNAJA1;STIP1;FKBP4;TMBIM6;EIF5;HNRNPU;DDX21;TA...
# Fatty Acid Metabolism      HSP90AA1;HSPH1;H2AZ1;KMT5A;ALDH3A2;ADSL;LGALS1...
# Oxidative Phosphorylation  ISCU;COX17;HSPA9;ATP5PO;NDUFS4;NQO2;SUCLA2;ETF...
# p53 Pathway                TOB1;STOM;H2AW;ERCC5;ISCU;CCNK;CD81;RPS27L;MKN...
# Estrogen Response Late     CDC20;KIF20A;FKBP4;TOB1;NMU;ALDH3A2;PDCD4;ETFB...
# Xenobiotic Metabolism      PTGES3;TMBIM6;SLC35B1;SLC1A5;LONP1;CYP1A2;KARS...
# IL-6/JAK/STAT3 Signaling   PTPN11;IL10RB;GRB2;CD9;ACVR1B;LTBR;IL15RA;TYK2...
# Allograft Rejection        RARS1;EIF3A;MRPL3;EIF3J;CD47;BCL3;HIF1A;MTIF2;...
#
#                                                                  ledge_genes
# Term
# Mitotic Spindle            CENPE;NEK2;CENPF;DLGAP5;CCNB2;BIRC5;PLK1;KIF20...
# G2-M Checkpoint            PTTG1;CKS2;CENPE;NEK2;UBE2S;CENPF;HMMR;CCNB2;B...
# Protein Secretion          ANP32E;ARF1;ARFGEF1;ATP1A1;CLTC;VPS4B;SCRN1;IG...
# Unfolded Protein Response  HSP90B1;KIF5B;HSPA5;CKS1B;YWHAZ;PAIP1;EIF4G1;T...
# Myc Targets V1             HSP90AB1;CDC20;KPNA2;HNRNPA1;HNRNPA3;GSPT1;CBX...
# TGF-beta Signaling         ARID4B;ID3;ID1;PPP1CA;SKIL;CTNNB1;RHOA;SPTBN1;...
# mTORC1 Signaling           HSP90B1;PLK1;AURKA;HSPD1;HSPA5;BUB1;STIP1;PSMC...
# E2F Targets                PTTG1;CKS2;CENPE;UBE2S;DLGAP5;HMMR;CCNB2;BIRC5...
# Spermatogenesis            NEK2;CCNB2;CDKN3;AURKA;BUB1;STRBP;KIF2C;PRKAR2...
# Androgen Response          PA2G4;XRCC6;LMAN1;MYL12A;SPDEF;GNAI3;DHCR24;SM...
# Myc Targets V2             PLK1;CBX3;HSPD1;HSPE1;DDX18;PA2G4;FARSA;LAS1L;...
# Apoptosis                  LMNA;DNAJA1;CDC25B;CREBBP;PDCD4;IGF2R;RARA;PPT...
# DNA Repair                 ARL6IP1;POLR3GL;ERCC5;COX17;ZWINT;RALA;POLR2A;...
# Apical Junction            NECTIN2;CAP1;ACTN4;ITGA2;CTNNA1;CRB3;PPP2R2C;S...
# PI3K/AKT/mTOR  Signaling   HSP90B1;ARF1;PPP1CA;ARHGDIA;CLTC;ACTR2;PTPN11;...
# heme Metabolism            TOP1;HDGF;CAST;GLRX5;GDE1;XPO7;RAD23A;PSMD9;NU...
# Glycolysis                 HMMR;AURKA;KIF20A;HSPA5;STMN1;FKBP4;DEPDC1;RAR...
# UV Response Up             DNAJA1;STIP1;FKBP4;TMBIM6;EIF5;HNRNPU;DDX21;TA...
# Fatty Acid Metabolism      HSP90AA1;HSPH1;H2AZ1;KMT5A;ALDH3A2;ADSL;LGALS1...
# Oxidative Phosphorylation  ISCU;COX17;HSPA9;ATP5PO;NDUFS4;NQO2;SUCLA2;ETF...
# p53 Pathway                TOB1;STOM;H2AW;ERCC5;ISCU;CCNK;CD81;RPS27L;MKN...
# Estrogen Response Late     CDC20;KIF20A;FKBP4;TOB1;NMU;ALDH3A2;PDCD4;ETFB...
# Xenobiotic Metabolism      PTGES3;TMBIM6;SLC35B1;SLC1A5;LONP1;CYP1A2;KARS...
# IL-6/JAK/STAT3 Signaling   PTPN11;IL10RB;GRB2;CD9;ACVR1B;LTBR;IL15RA;TYK2...
# Allograft Rejection        RARS1;EIF3A;MRPL3;EIF3J;CD47;BCL3;HIF1A;MTIF2;...

# %%
sc.var_names = sc.var["external_gene_name"].values
scanpy.tl.rank_genes_groups(sc, groupby="leiden", n_genes=len(sc.var_names),rankby_abs=True, method="wilcoxon")
# Out:
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'samples' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'project_id' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'phase' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromosome_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'external_gene_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_biotype' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'description' as categorical

# %%
rnaseq.dea.volcano_plot(sc, group="4", top=50)
