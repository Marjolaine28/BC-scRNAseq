# %%
# %load_ext autoreload
# %autoreload 1
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
import sys
import pandas as pd
import numpy as np
import importlib
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, PowerNorm
import scanpy
import gseapy as gp

# %%
sys.path.append("/u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/")

# %%
import rnaseq
importlib.reload(rnaseq)
# Out:
# <module 'rnaseq' from '/u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/rnaseq/__init__.py'>

# %%
# %%bash
# pwd
# Out:
# /u/davidm/Documents/Master-thesis/Projects/scBC-Analysis/0_Preprocessing/2_Cells-filtering/dsp762

# %%
# %%bash
# tar czf ./figs.tar.gz ./figs/*.pdf

# %% [markdown]
# ### Plotting parameters

# %%
# %matplotlib inline
plt.rcParams['figure.dpi'] = 110
plt.rcParams['font.size'] = 6

# %% [markdown]
# ### Genes lists

# %%
cell_cycle_genes = np.array(['MCM5', 'PCNA', 'TYMS', 'FEN1', 'MCM2', 'MCM4', 'RRM1', 'UNG',
       'GINS2', 'MCM6', 'CDCA7', 'DTL', 'PRIM1', 'UHRF1', 'HELLS', 'RFC2',
       'RPA2', 'NASP', 'RAD51AP1', 'GMNN', 'WDR76', 'SLBP', 'CCNE2',
       'UBR7', 'POLD3', 'MSH2', 'ATAD2', 'RAD51', 'RRM2', 'CDC45', 'CDC6',
       'EXO1', 'TIPIN', 'DSCC1', 'BLM', 'CASP8AP2', 'USP1', 'CLSPN',
       'POLA1', 'CHAF1B', 'BRIP1', 'E2F8', 'HMGB2', 'CDK1', 'NUSAP1',
       'UBE2C', 'BIRC5', 'TPX2', 'TOP2A', 'NDC80', 'CKS2', 'NUF2',
       'CKS1B', 'MKI67', 'TMPO', 'CENPF', 'TACC3', 'SMC4', 'CCNB2',
       'CKAP2L', 'CKAP2', 'AURKB', 'BUB1', 'KIF11', 'ANP32E', 'TUBB4B',
       'GTSE1', 'KIF20B', 'HJURP', 'CDCA3', 'CDC20', 'TTK', 'CDC25C',
       'KIF2C', 'RANGAP1', 'NCAPD2', 'DLGAP5', 'CDCA2', 'CDCA8', 'ECT2',
       'KIF23', 'HMMR', 'AURKA', 'PSRC1', 'ANLN', 'LBR', 'CKAP5', 'CENPE',
       'CTCF', 'NEK2', 'G2E3', 'GAS2L3', 'CBX5', 'CENPA'])

s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]

# %%
g2m_genes = ['ABL1', 'AMD1', 'ARID4A', 'ATF5', 'ATRX', 'AURKA', 'AURKB',
       'BARD1', 'BCL3', 'BIRC5', 'BRCA2', 'BUB1', 'BUB3', 'CASP8AP2',
       'CBX1', 'CCNA2', 'CCNB2', 'CCND1', 'CCNF', 'CCNT1', 'CDC20',
       'CDC25A', 'CDC25B', 'CDC27', 'CDC45', 'CDC6', 'CDC7', 'CDK1',
       'CDK4', 'CDKN1B', 'CDKN2C', 'CDKN3', 'CENPA', 'CENPE', 'CENPF',
       'CHAF1A', 'CHEK1', 'CHMP1A', 'CKS1B', 'CKS2', 'CTCF', 'CUL1',
       'CUL3', 'CUL4A', 'CUL5', 'DBF4', 'DDX39A', 'DKC1', 'DMD', 'DR1',
       'DTYMK', 'E2F1', 'E2F2', 'E2F3', 'E2F4', 'EFNA5', 'EGF', 'ESPL1',
       'EWSR1', 'EXO1', 'EZH2', 'FANCC', 'FBXO5', 'FOXN3', 'G3BP1',
       'GINS2', 'GSPT1', 'H2AX', 'H2AZ1', 'H2AZ2', 'H2BC12', 'HIF1A',
       'HIRA', 'HMGA1', 'HMGB3', 'HMGN2', 'HMMR', 'HNRNPD', 'HNRNPU',
       'HOXC10', 'HSPA8', 'HUS1', 'ILF3', 'INCENP', 'JPT1', 'KATNA1',
       'KIF11', 'KIF15', 'KIF20B', 'KIF22', 'KIF23', 'KIF2C', 'KIF4A',
       'KIF5B', 'KMT5A', 'KNL1', 'KPNA2', 'KPNB1', 'LBR', 'LIG3', 'LMNB1',
       'MAD2L1', 'MAP3K20', 'MAPK14', 'MARCKS', 'MCM2', 'MCM3', 'MCM5',
       'MCM6', 'MEIS1', 'MEIS2', 'MKI67', 'MNAT1', 'MT2A', 'MTF2',
       'MYBL2', 'MYC', 'NASP', 'NCL', 'NDC80', 'NEK2', 'NOLC1', 'NOTCH2',
       'NSD2', 'NUMA1', 'NUP50', 'NUP98', 'NUSAP1', 'ODC1', 'ODF2',
       'ORC5', 'ORC6', 'PAFAH1B1', 'PBK', 'PDS5B', 'PLK1', 'PLK4', 'PML',
       'POLA2', 'POLE', 'POLQ', 'PRC1', 'PRIM2', 'PRMT5', 'PRPF4B',
       'PTTG1', 'PTTG3P', 'PURA', 'RACGAP1', 'RAD21', 'RAD23B', 'RAD54L',
       'RASAL2', 'RBL1', 'RBM14', 'RPA2', 'RPS6KA5', 'SAP30', 'SFPQ',
       'SLC12A2', 'SLC38A1', 'SLC7A1', 'SLC7A5', 'SMAD3', 'SMARCC1',
       'SMC1A', 'SMC2', 'SMC4', 'SNRPD1', 'SQLE', 'SRSF1', 'SRSF10',
       'SRSF2', 'SS18', 'STAG1', 'STIL', 'STMN1', 'SUV39H1', 'SYNCRIP',
       'TACC3', 'TENT4A', 'TFDP1', 'TGFB1', 'TLE3', 'TMPO', 'TNPO2',
       'TOP1', 'TOP2A', 'TPX2', 'TRA2B', 'TRAIP', 'TROAP', 'TTK', 'UBE2C',
       'UBE2S', 'UCK2', 'UPF1', 'WRN', 'XPO1', 'YTHDC1']

# %% [markdown]
# ### Load sample

# %%
sample = "Sample_MCF7-labbo"
new_sample_name = "MCF7-labo-1"
quant_params = "trimmed-reads-cutadapt-all/decoys-k19-1.4.0/customWh-top-3000"
genref = "human/assembly__GRCh38-hg38/annotation__gencode/gencode_34"
project = "dsp762"
cell_line = "MCF7"

# %%
sc = rnaseq.readwrite.read_raw(project_id  = project, quant_tool = "alevin", samples = sample, genes_id = "ensembl_gene_id", quant_params = quant_params, genref = genref, cdna = "3' tag", exp = "sc")
sc.obs_names = sc.obs["CB"].tolist()
# Out:
# /home/arion/davidm/Data/datasets/raw/private/RNA-seq/sc/dsp762/quant/alevin/human/assembly__GRCh38-hg38/annotation__gencode/gencode_34/trimmed-reads-cutadapt-all/decoys-k19-1.4.0/customWh-top-3000
# Using BioMart Ensembl Genes 100 hsapiens_gene_ensembl for gene annotations.

# %%
rnaseq.setup.annotate_samples(sc, samples_annot_name = "samples", samples_annot = new_sample_name, ow = True)
rnaseq.setup.annotate_samples(sc, samples_annot_name = "cell_line", samples_annot = cell_line, ow = True)

rnaseq.setup.annotate_samples(sc, samples_annot_name = "total_UMIs", samples_annot = sc.X.toarray().sum(1).ravel())
rnaseq.setup.annotate_samples(sc, samples_annot_name = "#_genes", samples_annot = (sc.X.toarray() != 0).sum(1).ravel())
rnaseq.setup.annotate_samples(sc, samples_annot_name = "max_corr")
rnaseq.setup.annotate_samples(sc, samples_annot_name = "mt_frac")
rnaseq.setup.annotate_samples(sc, samples_annot_name = "rp_frac")

rnaseq.setup.annotate_genes(sc, "gene_biotype")
# Out:
# Annotating samples...
# Annotating cell_line...
# Annotating total_UMIs...
# Annotating #_genes...
# Annotating max_corr...
# Normalization by total UMIs...
# Log2 + 1 tranformation...
# Annotating mt_frac...
# Annotating chromosome_name using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...
# Annotating rp_frac...
# Annotating external_gene_name using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...
# Annotating gene_biotype using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...

# %%
sc._inplace_subset_obs(sc.obs["total_UMIs"] > 100)

# %%
sc.X.shape
# Out:
# (2459, 60240)

# %%
# x = sc.layers["raw"].toarray()[:, (sc.var["gene_biotype"] == "lncRNA") & (sc.var["external_gene_name"] != "MALAT1")]
x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "lncRNA"]
sc.obs["lncRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "rRNA"]
sc.obs["rRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "Mt_rRNA"]
sc.obs["Mt_rRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "protein_coding"]
sc.obs["protein_coding"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "processed_pseudogene"]
sc.obs["processed_pseudogene"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, [g.startswith("HSP") for g in sc.var["external_gene_name"]]]
sc.obs["hsp_frac"] = x.sum(1) / sc.obs["total_UMIs"]

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)

sc.var_names = sc.var["external_gene_name"].values
sc.var_names = np.array(sc.var_names.values)
sc.var_names_make_unique()
scanpy.tl.score_genes_cell_cycle(sc, s_genes=s_genes, g2m_genes=g2m_genes)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc_copy = sc.copy()

# %% [markdown]
# ### QC distributions

# %%
sc = sc_copy.copy()

# %%
plt.boxplot(sc.obs["total_UMIs"]);

# %%
_,ax = plt.subplots(figsize=(2.5,2))
rnaseq.plotting.loghist(sc.obs["total_UMIs"], bins=20, ax=ax, linewidth=0.1, edgecolor='black', fc = "white");
# ax.set_xlim(200,25000)
plt.axvline(2000, linewidth = 0.8, c = 'red')
plt.title(new_sample_name)
plt.ylabel("Fréquence")
plt.xlabel("Nombre de UMI")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Nombre de UMI')

# %%
_,ax = plt.subplots(figsize=(2.5,2))
plt.hist(sc.obs["max_corr"], bins=20, linewidth=0.1, edgecolor='black', fc = "white");
plt.title(new_sample_name)
plt.axvline(0.7, linewidth = 0.8, c = 'red')
plt.ylabel("Fréquence")
plt.xlabel("Rmax")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Rmax')

# %%
_,ax = plt.subplots(figsize=(2.5,2))
plt.hist(sc.obs["Mt_rRNA"], bins=20, linewidth=0.1, edgecolor='black', fc = "white");
plt.title(new_sample_name)
plt.axvline(0.03, linewidth = 0.8, c = 'red')
plt.ylabel("Fréquence")
plt.xlabel("Fraction de Mt_rRNA")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Fraction de Mt_rRNA')

# %% [markdown]
# ### Explore sample

# %%
sc = sc_copy.copy()

# %%
metrics = ['total_UMIs', '#_genes', 'max_corr', 'MappingRate','DedupRate', 'mt_frac', 'rp_frac']
powers_metrics = [0.1,0.3,0.8,1.3,1.5,0.5,1.2]

biotypes = ['rRNA', 'Mt_rRNA', 'lncRNA', 'processed_pseudogene', 'protein_coding', 'G2M_score', 'hsp_frac', 'marker']
powers_biotypes = [1,0.5,1,0.5,1.8,0.5, 0.5, 1]

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)
scanpy.pp.pca(sc, n_comps=50)
scanpy.pp.neighbors(sc, n_pcs=20, n_neighbors=15)
scanpy.tl.umap(sc, n_components=2)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc.obs["marker"] = sc.X.toarray()[:, sc.var["external_gene_name"].values == "CDH1"] # HSPA5 SERP1

# %%
scatt = plt.subplots(figsize=(10,2.5), sharey=True)
for i,(c,p) in enumerate(zip(biotypes,powers_biotypes)):
    axi = plt.subplot(2,9,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 2, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(biotypes):
    axi = plt.subplot(2,9,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    plt.hist(sc.obs[c],  bins = 20, color="white", edgecolor="gray", linewidth = 0.3);

# %%
scatt = plt.subplots(figsize=(9.5,2.5), sharey=True)
for i,(c,p) in enumerate(zip(metrics,powers_metrics)):
    axi = plt.subplot(2,8,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 1.5, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(metrics):
    axi = plt.subplot(2,8,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    if c in ["total_UMIs", "#_genes"] :
        rnaseq.plotting.loghist(sc.obs[c], bins=20, ax=axi, linewidth=0.3, color="white", edgecolor="gray");
    else :
        plt.hist(sc.obs[c],  bins = 15, color="white", edgecolor="gray", linewidth = 0.3);

# %% [markdown]
# ### Filter sample

# %%
sc = sc_copy.copy()

# %%
sc._inplace_subset_obs(sc.obs["total_UMIs"] > 1500)
sc._inplace_subset_obs(sc.obs["mt_frac"] < 0.15)

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)
scanpy.pp.pca(sc, n_comps=50)
scanpy.pp.neighbors(sc, n_pcs=20, n_neighbors=15)
scanpy.tl.umap(sc, n_components=2)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc.obs["marker"] = sc.X.toarray()[:, sc.var["external_gene_name"].values == "CDH1"] # HSPA5 SERP1

# %%
scatt = plt.subplots(figsize=(10,2.5), sharey=True)
for i,(c,p) in enumerate(zip(biotypes,powers_biotypes)):
    axi = plt.subplot(2,9,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 2, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(biotypes):
    axi = plt.subplot(2,9,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    plt.hist(sc.obs[c],  bins = 20, color="white", edgecolor="gray", linewidth = 0.3);

# %%
scatt = plt.subplots(figsize=(9.5,2.5), sharey=True)
for i,(c,p) in enumerate(zip(metrics,powers_metrics)):
    axi = plt.subplot(2,8,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 1.5, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(metrics):
    axi = plt.subplot(2,8,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    if c in ["total_UMIs", "#_genes"] :
        rnaseq.plotting.loghist(sc.obs[c], bins=20, ax=axi, linewidth=0.3, color="white", edgecolor="gray");
    else :
        plt.hist(sc.obs[c],  bins = 15, color="white", edgecolor="gray", linewidth = 0.3);

# %%
sc.X.shape
# Out:
# (404, 60240)

# %% [markdown]
# ### Alevin comparison

# %%
quant_params_default = "trimmed-reads-cutadapt-all/decoys-k31-1.4.0/default"
whitelist_default = pd.read_table(f"/home/arion/davidm/Data/datasets/raw/private/RNA-seq/sc/{project}/quant/alevin/{genref}/{quant_params_default}/{sample}/alevin/whitelist.txt", header=None)
cbs_default = pd.read_table(f"/home/arion/davidm/Data/datasets/raw/private/RNA-seq/sc/{project}/quant/alevin/{genref}/{quant_params_default}/{sample}/alevin/quants_mat_rows.txt", header=None)

# %%
len(cbs_default)
# Out:
# 325

# %%
len(whitelist_default)
# Out:
# 106

# %%
scatt = plt.subplots(figsize=(2.5,2))

i = np.array([cb in whitelist_default[0].values for cb in sc.obs_names])
plt.scatter(sc.obsm["X_umap"][:,0][i], sc.obsm["X_umap"][:,1][i], linewidths=0.35, edgecolors = "black", \
            s = 10, vmin = -0.5, vmax = 1.5, color = "white")
plt.scatter(sc.obsm["X_umap"][:,0][~i], sc.obsm["X_umap"][:,1][~i],\
            s = 12, vmin = -0.5, vmax = 1.5, alpha=0.35, color = "indianred", edgecolors = "black", linewidths=0.1)

# %%
scatt = plt.subplots(figsize=(2.5,2))

i = np.array([cb in cbs_default[0].values for cb in sc.obs_names])
plt.scatter(sc.obsm["X_umap"][:,0][i], sc.obsm["X_umap"][:,1][i], linewidths=0.35, edgecolors = "black", \
            s = 10, vmin = -0.5, vmax = 1.5, color = "white")
plt.scatter(sc.obsm["X_umap"][:,0][~i], sc.obsm["X_umap"][:,1][~i],\
            s = 12, vmin = -0.5, vmax = 1.5, alpha=0.35, color = "indianred", edgecolors = "black", linewidths=0.1)

# %%
sc.obs["alevin"] = np.array([cb in cbs_default.values for cb in sc.obs_names]).astype(int).astype(str)

# %%
sc.var_names = sc.var["external_gene_name"].values
scanpy.tl.rank_genes_groups(sc, groupby="alevin", n_genes=len(sc.var_names),rankby_abs=True, method="wilcoxon")
# Out:
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'samples' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'project_id' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cell_line' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'phase' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'alevin' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromosome_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'external_gene_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_biotype' as categorical

# %%
rnaseq.dea.volcano_plot(sc, group="0", top=20, show_genes='up')

# %% [markdown]
# ### Save filtered data

# %%
rnaseq.readwrite.write_filtered(sc)
# Out:
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'samples' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'project_id' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cell_line' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'phase' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromosome_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'external_gene_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_biotype' as categorical

# %%
del sc, sc_copy

# %% [markdown]
# ### Heterogeneity analysis

# %%
scanpy.tl.leiden(sc, resolution=0.4)

scatt,_ = plt.subplots(figsize=(3,2))

rnaseq.plotting.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], color = sc.obs["leiden"], \
    s = 20, xlabel="UMAP1", ylabel="UMAP2", color_title = "clusters",\
    title = new_sample_name, linewidth=0.15, fig = scatt)

# %%
rnaseq.setup.annotate_genes(sc, 'description')
# Out:
# Annotating description using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...

# %%
i = sc.obs["leiden"] != '0'
gene_exp = pd.DataFrame(sc.X.toarray()[i].T, columns = sc.obs["CB"].values[i])
class_vector = (sc.obs["leiden"].values[i] == '2').astype(str)
class_vector = np.where(class_vector == 'True', "cluster", class_vector) 
class_vector = np.where(class_vector == 'False', "rest", class_vector)

# %%
idx = np.argsort(class_vector)
gene_exp = gene_exp[gene_exp.columns[idx]]
gene_exp.insert(0, "DESCRIPTION", sc.var["description"].values, True)
gene_exp.insert(0, "NAME", sc.var["external_gene_name"].values, True)

class_vector = list(class_vector[idx])

# %%
gs_res = gp.gsea(gene_exp, # ordata='./P53_resampling_data.txt'
                 'MSigDB_Hallmark_2020', # enrichr library names
                  class_vector,
                 # set permutation_type to phenotype if samples >=15
                 permutation_type='phenotype',
                 permutation_num=100, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 method='signal_to_noise',
                 processes=4, seed= 7,
                 format='png')
# Out:
# 2021-12-14 19:36:55,582 Warning: dropping duplicated gene names, only keep the first values

# %%
res = gs_res.res2d.sort_values(by='nes', ascending=False)
res = res.loc[res.index[(res['fdr'].values < 0.05) & (res['pval'].values < 0.05)]]

# %%
res
# Out:
#                                      es       nes      pval       fdr  \
# Term
# Estrogen Response Late         0.461055  2.043699  0.000000  0.000000
# Estrogen Response Early        0.395835  1.816704  0.000000  0.003040
# Apical Surface                 0.452198  1.540345  0.037037  0.030395
# heme Metabolism               -0.345106 -1.614230  0.000000  0.024103
# mTORC1 Signaling              -0.339194 -1.620738  0.000000  0.019141
# Hypoxia                       -0.349559 -1.650937  0.000000  0.013558
# IL-6/JAK/STAT3 Signaling      -0.460778 -1.696916  0.000000  0.009641
# Adipogenesis                  -0.355024 -1.735332  0.000000  0.007748
# KRAS Signaling Dn             -0.419586 -1.777089  0.000000  0.000000
# Myc Targets V2                -0.439079 -1.813958  0.000000  0.000000
# Xenobiotic Metabolism         -0.372839 -1.870021  0.000000  0.000000
# Complement                    -0.419861 -1.899874  0.000000  0.000000
# Coagulation                   -0.429685 -1.949547  0.000000  0.000000
# Myc Targets V1                -0.435912 -1.959834  0.000000  0.000000
# UV Response Up                -0.441854 -2.029797  0.000000  0.000000
# Apical Junction               -0.432209 -2.032678  0.000000  0.000000
# Apoptosis                     -0.440056 -2.052094  0.000000  0.000000
# PI3K/AKT/mTOR  Signaling      -0.515855 -2.257152  0.000000  0.000000
# DNA Repair                    -0.469152 -2.391724  0.000000  0.000000
# p53 Pathway                   -0.554573 -2.563699  0.000000  0.000000
# TNF-alpha Signaling via NF-kB -0.564585 -2.640876  0.000000  0.000000
#
#                                geneset_size  matched_size  \
# Term
# Estrogen Response Late                  200           183
# Estrogen Response Early                 200           190
# Apical Surface                           44            25
# heme Metabolism                         200           154
# mTORC1 Signaling                        200           189
# Hypoxia                                 200           150
# IL-6/JAK/STAT3 Signaling                 87            43
# Adipogenesis                            200           168
# KRAS Signaling Dn                       200            77
# Myc Targets V2                           58            58
# Xenobiotic Metabolism                   200           133
# Complement                              200           112
# Coagulation                             138            65
# Myc Targets V1                          200           198
# UV Response Up                          158           128
# Apical Junction                         200           126
# Apoptosis                               161           123
# PI3K/AKT/mTOR  Signaling                105            90
# DNA Repair                              150           141
# p53 Pathway                             200           174
# TNF-alpha Signaling via NF-kB           200           152
#
#                                                                            genes  \
# Term
# Estrogen Response Late         SLC26A2;XBP1;KLK11;GLA;ISG20;COX6C;TFF1;TPD52L...
# Estrogen Response Early        SLC26A2;XBP1;RHOBTB3;SLC39A6;GLA;TFF1;TPD52L1;...
# Apical Surface                 GSTM3;HSPB1;AFAP1L2;SHROOM2;BRCA1;ADIPOR2;SULF...
# heme Metabolism                ABCG2;PRDX2;HTATIP2;NR3C1;MXI1;ISCA1;MGST3;SLC...
# mTORC1 Signaling               XBP1;GLA;IGFBP5;PSMA4;INSIG1;DDIT4;NUPR1;CANX;...
# Hypoxia                        ISG20;STC2;DDIT4;GALK1;COL5A1;AKAP12;MIF;BCL2;...
# IL-6/JAK/STAT3 Signaling       PTPN11;IRF9;IFNAR1;IL6ST;IL17RB;STAT1;TGFB1;PT...
# Adipogenesis                   REEP5;TST;ETFB;DHRS7;MTCH2;PRDX3;PDCD4;ATP5PO;...
# KRAS Signaling Dn              SLC6A3;MFSD6;FGGY;SGK1;NR6A1;PDE6B;ARHGDIG;THN...
# Myc Targets V2                 NPM1;CBX3;PHB;DUSP2;NDUFAF4;FARSA;PLK1;PPRC1;S...
# Xenobiotic Metabolism          ID2;AKR1C2;GSTO1;DHRS7;TMBIM6;IGFBP4;EPHX1;MCC...
# Complement                     CALM1;SERPINA1;PFN1;CD59;LGALS3;DOCK9;FYN;LTA4...
# Coagulation                    SERPINA1;PRSS23;RAC1;THBS1;GNG12;MSRB2;FYN;F12...
# Myc Targets V1                 RPS6;PABPC1;RPS3;PSMA7;PSMA4;AP3S1;HDDC2;NPM1;...
# UV Response Up                 TST;EIF5;TMBIM6;RET;EPHX1;FGF18;CYB5R1;EPCAM;G...
# Apical Junction                CDSN;INSIG1;PFN1;MDK;PIK3R3;EVL;RSU1;MPZL1;NEC...
# Apoptosis                      ISG20;TXNIP;HSPB1;TOP2A;KRT18;PDCD4;LGALS3;IFI...
# PI3K/AKT/mTOR  Signaling       PFN1;CDK1;PTPN11;RAC1;PIK3R3;PRKAR2A;CLTC;PIN1...
# DNA Repair                     DAD1;IMPDH2;POLR2J;POLB;NELFE;TMED2;MPC2;RFC2;...
# p53 Pathway                    TPD52L1;TXNIP;H2AJ;DDIT4;NUPR1;RACK1;HINT1;EPH...
# TNF-alpha Signaling via NF-kB  AREG;ID2;ATP2B1;TIPARP;DUSP2;SLC2A6;KLF6;IL6ST...
#
#                                                                      ledge_genes
# Term
# Estrogen Response Late         SLC26A2;XBP1;KLK11;GLA;ISG20;COX6C;TFF1;TPD52L...
# Estrogen Response Early        SLC26A2;XBP1;RHOBTB3;SLC39A6;GLA;TFF1;TPD52L1;...
# Apical Surface                                                       GSTM3;HSPB1
# heme Metabolism                CLCN3;SLC10A3;FOXO3;FOXJ2;ARL2BP;CDR2;CROCCP2;...
# mTORC1 Signaling               SERPINH1;ACTR2;GSK3B;MCM4;ETF1;UBE2D3;GSR;SEC1...
# Hypoxia                        SDC4;IER3;BTG1;GPI;EFNA3;MAP3K1;ANKZF1;FAM162A...
# IL-6/JAK/STAT3 Signaling       TNFRSF1A;SOCS1;HAX1;IRF1;GRB2;LTBR;FAS;STAT2;P...
# Adipogenesis                   BCKDHA;CHCHD10;ADCY6;SCP2;IDH3G;PEX14;UCK1;UBQ...
# KRAS Signaling Dn              KMT2D;SLC25A23;MTHFR;EDN2;SYNPO;KCNMB1;TCF7L1;...
# Myc Targets V2                 MCM5;HK2;WDR43;NOP56;WDR74;IMP4;PRMT3;TCOF1;MC...
# Xenobiotic Metabolism          FBP1;GSR;SLC35B1;DDT;TNFRSF1A;LPIN2;TGFB2;PTGR...
# Complement                     PCLO;DYRK2;CBLB;PIK3CA;GNB4;PRKCD;AKAP10;DGKH;...
# Coagulation                    CAPN2;PLAU;THBD;USP11;TIMP1;CTSB;S100A13;CLU;C...
# Myc Targets V1                 CDK4;EIF3B;RRP9;EXOSC7;HNRNPA2B1;VBP1;IARS1;PS...
# UV Response Up                 TARS1;PRKCD;KLHDC3;IGFBP2;STK25;CLTB;MARK2;BTG...
# Apical Junction                SHC1;PBX2;IKBKG;GRB7;ITGA3;VASP;ITGB1;ACTG1;TI...
# Apoptosis                      BTG3;PAK1;ETF1;BIK;PPP2R5B;EGR3;APP;GSR;PPP3R1...
# PI3K/AKT/mTOR  Signaling       SLC2A1;GRK2;NOD1;ARPC3;PIKFYVE;VAV3;ACTR2;GSK3...
# DNA Repair                     POLR2I;TAF10;TYMS;ADCY6;CSTF3;POLR2E;DDB1;POLR...
# p53 Pathway                    PRKAB1;COQ8A;FOXO3;KIF13B;ZMAT3;TPRKB;TRAFD1;P...
# TNF-alpha Signaling via NF-kB  BTG3;PNRC1;PLAU;EGR3;TNIP2;CEBPB;IFIH1;ZC3H12A...

# %%
res
# Out:
#                                   es       nes      pval       fdr  \
# Term
# Estrogen Response Early     0.363990  1.581563  0.029412  0.046749
# Adipogenesis               -0.336839 -1.577493  0.000000  0.041073
# Wnt-beta Catenin Signaling -0.466207 -1.578101  0.000000  0.045637
# TGF-beta Signaling         -0.415651 -1.624132  0.000000  0.038506
# Notch Signaling            -0.463733 -1.625947  0.000000  0.044007
# p53 Pathway                -0.321519 -1.679913  0.000000  0.034228
# DNA Repair                 -0.357528 -1.698611  0.000000  0.041073
# G2-M Checkpoint            -0.369107 -1.727129  0.000000  0.034228
# UV Response Up             -0.416038 -1.856083  0.000000  0.034228
# PI3K/AKT/mTOR  Signaling   -0.465591 -2.089119  0.000000  0.000000
#
#                             geneset_size  matched_size  \
# Term
# Estrogen Response Early              200           185
# Adipogenesis                         200           161
# Wnt-beta Catenin Signaling            42            27
# TGF-beta Signaling                    54            46
# Notch Signaling                       32            26
# p53 Pathway                          200           172
# DNA Repair                           150           140
# G2-M Checkpoint                      200           162
# UV Response Up                       158           125
# PI3K/AKT/mTOR  Signaling             105            84
#
#                                                                         genes  \
# Term
# Estrogen Response Early     KRT18;TPD52L1;KRT19;STC2;KRT8;AMFR;CLIC3;CCN5;...
# Adipogenesis                BCL2L13;HSPB8;BCL6;ATP5PO;SLC19A1;PDCD4;RTN3;P...
# Wnt-beta Catenin Signaling  HDAC5;CSNK1E;DVL2;MYC;HEY2;MAML1;FRAT1;AXIN1;H...
# TGF-beta Signaling          THBS1;SPTBN1;TGIF1;TGFB1;SKIL;SKI;SMAD3;FKBP1A...
# Notch Signaling             CCND1;ARRB1;SAP30;FBXW11;RBX1;NOTCH3;MAML2;JAG...
# p53 Pathway                 RPL18;RACK1;RPS12;TPD52L1;RPL36;JUN;SLC7A11;TG...
# DNA Repair                  POLR1D;USP11;HPRT1;TAF10;TARBP2;DDB2;NME4;CLP1...
# G2-M Checkpoint             HSPA8;CCND1;SQLE;HMGA1;SMARCC1;ATF5;GINS2;CDC2...
# UV Response Up              ASNS;UROD;CA2;PPIF;ATF3;EIF2S3;RAB27A;ENO2;SEL...
# PI3K/AKT/mTOR  Signaling    PRKAG1;RIT1;RPS6KA3;ECSIT;CAB39L;PITX2;MKNK2;V...
#
#                                                                   ledge_genes
# Term
# Estrogen Response Early     KRT18;TPD52L1;KRT19;STC2;KRT8;AMFR;CLIC3;CCN5;...
# Adipogenesis                RNF11;GBE1;ARAF;COQ9;AK2;SLC25A1;TANK;CDKN2C;N...
# Wnt-beta Catenin Signaling       PSEN2;NOTCH1;DKK1;NCSTN;NUMB;TP53;DLL1;PPARD
# TGF-beta Signaling          TJP1;HIPK2;APC;KLF10;PPM1A;TRIM33;ID2;XIAP;SMA...
# Notch Signaling                  PSEN2;NOTCH1;LFNG;HES1;SKP1;DLL1;APH1A;PPARD
# p53 Pathway                 AK1;ST14;PHLDA3;DRAM1;IFI30;H2AJ;RAB40C;CD81;N...
# DNA Repair                  NME1;POLD3;CANT1;SUPT4H1;SURF1;POLR2C;ZNRD1;PO...
# G2-M Checkpoint             SLC38A1;POLE;ODC1;ILF3;TPX2;CKS2;TLE3;MCM3;UBE...
# UV Response Up              CNP;RHOB;DNAJA1;BTG3;CREG1;DNAJB1;NR4A1;NPTXR;...
# PI3K/AKT/mTOR  Signaling    RPS6KA1;CDK4;TIAM1;HRAS;GSK3B;MKNK1;CSNK2B;PTP...

# %%
res
# Out:
#                                   es       nes      pval       fdr  \
# Term
# PI3K/AKT/mTOR  Signaling    0.465591  2.125291  0.000000  0.000000
# UV Response Up              0.416038  2.109748  0.000000  0.000000
# E2F Targets                 0.395358  1.828639  0.000000  0.036889
# G2-M Checkpoint             0.369107  1.809399  0.000000  0.036889
# DNA Repair                  0.357528  1.808708  0.000000  0.029511
# TGF-beta Signaling          0.415651  1.702422  0.000000  0.043038
# Oxidative Phosphorylation   0.366037  1.692585  0.000000  0.036889
# Adipogenesis                0.336839  1.676714  0.000000  0.036889
# Wnt-beta Catenin Signaling  0.466207  1.673955  0.037037  0.032791
# Mitotic Spindle             0.345735  1.628013  0.000000  0.033200
#
#                             geneset_size  matched_size  \
# Term
# PI3K/AKT/mTOR  Signaling             105            84
# UV Response Up                       158           125
# E2F Targets                          200           166
# G2-M Checkpoint                      200           162
# DNA Repair                           150           140
# TGF-beta Signaling                    54            46
# Oxidative Phosphorylation            200           199
# Adipogenesis                         200           161
# Wnt-beta Catenin Signaling            42            27
# Mitotic Spindle                      199           174
#
#                                                                         genes  \
# Term
# PI3K/AKT/mTOR  Signaling    ARHGDIA;PFN1;CALR;AKT1;RAF1;CFL1;CLTC;PPP1CA;U...
# UV Response Up              EIF5;TMBIM6;HYAL2;YKT6;FEN1;NFKBIA;IL6ST;POLE3...
# E2F Targets                 XPO1;PPM1D;RANBP1;ASF1A;EIF2S1;NAA38;GSPT1;KIF...
# G2-M Checkpoint             XPO1;PRPF4B;NCL;STIL;CCNT1;GSPT1;ARID4A;KIF22;...
# DNA Repair                  ADRM1;TYMS;FEN1;EDF1;GTF2A2;POLE4;RAE1;POLR2H;...
# TGF-beta Signaling          CDH1;HDAC1;CDK9;PPP1CA;UBE2D3;SMAD7;XIAP;ID2;T...
# Oxidative Phosphorylation   COX6A1;UQCRFS1;ATP6AP1;MRPS12;NDUFAB1;NDUFS6;H...
# Adipogenesis                COX6A1;NDUFAB1;GPAT4;G3BP2;STOM;ABCB8;TOB1;COX...
# Wnt-beta Catenin Signaling  PPARD;DLL1;TP53;NUMB;NCSTN;DKK1;NOTCH1;PSEN2;A...
# Mitotic Spindle             BCAR1;ARHGDIA;STAU1;KIF22;CNTROB;RALBP1;MYO9B;...
#
#                                                                   ledge_genes
# Term
# PI3K/AKT/mTOR  Signaling    ARHGDIA;PFN1;CALR;AKT1;RAF1;CFL1;CLTC;PPP1CA;U...
# UV Response Up              EIF5;TMBIM6;HYAL2;YKT6;FEN1;NFKBIA;IL6ST;POLE3...
# E2F Targets                 XPO1;PPM1D;RANBP1;ASF1A;EIF2S1;NAA38;GSPT1;KIF...
# G2-M Checkpoint             XPO1;PRPF4B;NCL;STIL;CCNT1;GSPT1;ARID4A;KIF22;...
# DNA Repair                  ADRM1;TYMS;FEN1;EDF1;GTF2A2;POLE4;RAE1;POLR2H;...
# TGF-beta Signaling          CDH1;HDAC1;CDK9;PPP1CA;UBE2D3;SMAD7;XIAP;ID2;T...
# Oxidative Phosphorylation   COX6A1;UQCRFS1;ATP6AP1;MRPS12;NDUFAB1;NDUFS6;H...
# Adipogenesis                COX6A1;NDUFAB1;GPAT4;G3BP2;STOM;ABCB8;TOB1;COX...
# Wnt-beta Catenin Signaling       PPARD;DLL1;TP53;NUMB;NCSTN;DKK1;NOTCH1;PSEN2
# Mitotic Spindle             BCAR1;ARHGDIA;STAU1;KIF22;CNTROB;RALBP1;MYO9B;...

# %%
sc.var_names = sc.var["external_gene_name"].values
scanpy.tl.rank_genes_groups(sc, groupby="leiden", reference='1',n_genes=len(sc.var_names),rankby_abs=True, method="wilcoxon")
# Out:
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'samples' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'project_id' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'phase' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromosome_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'external_gene_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_biotype' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'description' as categorical

# %%
rnaseq.dea.volcano_plot(sc, group="0", top=50)

# %%
rnaseq.dea.enrichr(sc, group='0', libraries="MSigDB_Hallmark_2020")
# Out:
# /u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/rnaseq/dea.py:38: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = pd.DataFrame(np.array(data[gene_set_library])[:,1:], columns=["Term", "P-value", "Z-score", "Combined Score", "Genes", "Adjusted P-value", "Old P-value", "Old adjusted P-value"])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>Term</th>
#       <th>P-value</th>
#       <th>Z-score</th>
#       <th>Combined Score</th>
#       <th>Genes</th>
#       <th>Adjusted P-value</th>
#       <th>Old P-value</th>
#       <th>Old adjusted P-value</th>
#       <th>color</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Myc Targets V1</td>
#       <td>0.0</td>
#       <td>9.0092</td>
#       <td>220.654566</td>
#       <td>[H2AZ1, EIF4A1, HDDC2, CBX3, PTGES3, RPS5, CNBP, RPS6, HSPE1, RPL6, PSMA7, PSMA4, SNRPD1, CANX, SNRPD3, HNRNPC, AP3S1, PABPC1]</td>
#       <td>-9.003332</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Estrogen Response Early</td>
#       <td>0.000001</td>
#       <td>6.187166</td>
#       <td>87.922879</td>
#       <td>[XBP1, SLC26A2, KRT8, RHOBTB3, TPD52L1, AREG, PRSS23, MLPH, STC2, BAG1, SLC39A6, TFF1, GLA]</td>
#       <td>-4.839115</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Estrogen Response Late</td>
#       <td>0.000004</td>
#       <td>5.654857</td>
#       <td>70.023727</td>
#       <td>[ISG20, XBP1, SLC26A2, ID2, BAG1, TFF1, COX6C, TPD52L1, PRSS23, AREG, GLA, KLK11]</td>
#       <td>-4.221493</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>Oxidative Phosphorylation</td>
#       <td>0.000024</td>
#       <td>5.132704</td>
#       <td>54.625299</td>
#       <td>[HSPA9, ATP5PF, NDUFB8, ATP6V0E1, ATP5F1B, ATP5PD, MDH1, NDUFB2, COX6C, SLC25A5, ATP5F1D]</td>
#       <td>-3.590612</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>Protein Secretion</td>
#       <td>0.000132</td>
#       <td>6.848265</td>
#       <td>61.193004</td>
#       <td>[CD63, TMED10, TMX1, COPB1, GNAS, AP3S1, GLA]</td>
#       <td>-2.946161</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>Unfolded Protein Response</td>
#       <td>0.000361</td>
#       <td>5.744991</td>
#       <td>45.539147</td>
#       <td>[HSPA9, EIF4A1, RPS14, XBP1, STC2, CALR, LSM4]</td>
#       <td>-2.587230</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>G2-M Checkpoint</td>
#       <td>0.000582</td>
#       <td>4.117988</td>
#       <td>30.676156</td>
#       <td>[H2AZ1, HSPA8, ILF3, SFPQ, SNRPD1, NCL, STMN1, KIF22, HIF1A]</td>
#       <td>-2.446822</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>mTORC1 Signaling</td>
#       <td>0.002449</td>
#       <td>3.625</td>
#       <td>21.79329</td>
#       <td>[HSPA9, XBP1, PSMA4, INSIG1, CANX, CALR, HSPE1, GLA]</td>
#       <td>-1.918969</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>Reactive Oxygen Species Pathway</td>
#       <td>0.002522</td>
#       <td>7.655313</td>
#       <td>45.798409</td>
#       <td>[PRDX2, TXN, FTL, LAMTOR5]</td>
#       <td>-1.918969</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>E2F Targets</td>
#       <td>0.009154</td>
#       <td>3.141318</td>
#       <td>14.743936</td>
#       <td>[H2AZ1, POLE4, PNN, ILF3, STMN1, KIF22, PPM1D]</td>
#       <td>-1.404915</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>7</td>
#       <td>mTORC1 Signaling</td>
#       <td>0.006171</td>
#       <td>5.835847</td>
#       <td>29.692373</td>
#       <td>[XBP1, PSMA4, INSIG1, GLA]</td>
#       <td>1.619834</td>
#       <td>0</td>
#       <td>0</td>
#       <td>green</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>6</td>
#       <td>Interferon Gamma Response</td>
#       <td>0.006171</td>
#       <td>5.835847</td>
#       <td>29.692373</td>
#       <td>[ISG20, PSME2, TXNIP, HIF1A]</td>
#       <td>1.619834</td>
#       <td>0</td>
#       <td>0</td>
#       <td>green</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>5</td>
#       <td>Myogenesis</td>
#       <td>0.006171</td>
#       <td>5.835847</td>
#       <td>29.692373</td>
#       <td>[STC2, BAG1, TPD52L1, SGCG]</td>
#       <td>1.619834</td>
#       <td>0</td>
#       <td>0</td>
#       <td>green</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>4</td>
#       <td>Interferon Alpha Response</td>
#       <td>0.005381</td>
#       <td>9.042401</td>
#       <td>47.245191</td>
#       <td>[ISG20, PSME2, TXNIP]</td>
#       <td>1.619834</td>
#       <td>0</td>
#       <td>0</td>
#       <td>green</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>8</td>
#       <td>Myc Targets V1</td>
#       <td>0.006171</td>
#       <td>5.835847</td>
#       <td>29.692373</td>
#       <td>[H2AZ1, HDDC2, PSMA4, AP3S1]</td>
#       <td>1.619834</td>
#       <td>0</td>
#       <td>0</td>
#       <td>green</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>3</td>
#       <td>Epithelial Mesenchymal Transition</td>
#       <td>0.000823</td>
#       <td>7.440422</td>
#       <td>52.841769</td>
#       <td>[CADM1, BASP1, ID2, AREG, SGCG]</td>
#       <td>2.142345</td>
#       <td>0</td>
#       <td>0</td>
#       <td>green</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2</td>
#       <td>Protein Secretion</td>
#       <td>0.000421</td>
#       <td>12.498425</td>
#       <td>97.147149</td>
#       <td>[TMX1, GNAS, AP3S1, GLA]</td>
#       <td>2.308716</td>
#       <td>0</td>
#       <td>0</td>
#       <td>green</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1</td>
#       <td>Estrogen Response Early</td>
#       <td>0.0</td>
#       <td>16.488722</td>
#       <td>324.323359</td>
#       <td>[XBP1, SLC26A2, STC2, BAG1, SLC39A6, RHOBTB3, TFF1, TPD52L1, GLA, AREG]</td>
#       <td>7.299276</td>
#       <td>0</td>
#       <td>0</td>
#       <td>green</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>0</td>
#       <td>Estrogen Response Late</td>
#       <td>0.0</td>
#       <td>18.528588</td>
#       <td>418.253053</td>
#       <td>[ISG20, XBP1, SLC26A2, ID2, BAG1, TFF1, COX6C, TPD52L1, GLA, AREG, KLK11]</td>
#       <td>8.259431</td>
#       <td>0</td>
#       <td>0</td>
#       <td>green</td>
#     </tr>
#   </tbody>
# </table>
