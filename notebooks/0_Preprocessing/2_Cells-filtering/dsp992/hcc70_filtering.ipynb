# %%
# %load_ext autoreload
# %autoreload 1
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
import sys
import pandas as pd
import numpy as np
import importlib
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, PowerNorm
import scanpy
import gseapy as gp

# %%
sys.path.append("/u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/")

# %%
import rnaseq
importlib.reload(rnaseq)
# Out:
# <module 'rnaseq' from '/u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/rnaseq/__init__.py'>

# %%
# %%bash
# pwd
# Out:
# /u/davidm/Documents/Master-thesis/Projects/scBC-Analysis/0_Preprocessing/2_Cells-filtering/dsp992

# %%
# %%bash
# tar czf ./figs.tar.gz ./figs/*.pdf

# %% [markdown]
# ### Plotting parameters

# %%
# %matplotlib inline
plt.rcParams['figure.dpi'] = 110
plt.rcParams['font.size'] = 6

# %% [markdown]
# ### Genes lists

# %%
cell_cycle_genes = np.array(['MCM5', 'PCNA', 'TYMS', 'FEN1', 'MCM2', 'MCM4', 'RRM1', 'UNG',
       'GINS2', 'MCM6', 'CDCA7', 'DTL', 'PRIM1', 'UHRF1', 'HELLS', 'RFC2',
       'RPA2', 'NASP', 'RAD51AP1', 'GMNN', 'WDR76', 'SLBP', 'CCNE2',
       'UBR7', 'POLD3', 'MSH2', 'ATAD2', 'RAD51', 'RRM2', 'CDC45', 'CDC6',
       'EXO1', 'TIPIN', 'DSCC1', 'BLM', 'CASP8AP2', 'USP1', 'CLSPN',
       'POLA1', 'CHAF1B', 'BRIP1', 'E2F8', 'HMGB2', 'CDK1', 'NUSAP1',
       'UBE2C', 'BIRC5', 'TPX2', 'TOP2A', 'NDC80', 'CKS2', 'NUF2',
       'CKS1B', 'MKI67', 'TMPO', 'CENPF', 'TACC3', 'SMC4', 'CCNB2',
       'CKAP2L', 'CKAP2', 'AURKB', 'BUB1', 'KIF11', 'ANP32E', 'TUBB4B',
       'GTSE1', 'KIF20B', 'HJURP', 'CDCA3', 'CDC20', 'TTK', 'CDC25C',
       'KIF2C', 'RANGAP1', 'NCAPD2', 'DLGAP5', 'CDCA2', 'CDCA8', 'ECT2',
       'KIF23', 'HMMR', 'AURKA', 'PSRC1', 'ANLN', 'LBR', 'CKAP5', 'CENPE',
       'CTCF', 'NEK2', 'G2E3', 'GAS2L3', 'CBX5', 'CENPA'])

s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]

# %%
g2m_genes = ['ABL1', 'AMD1', 'ARID4A', 'ATF5', 'ATRX', 'AURKA', 'AURKB',
       'BARD1', 'BCL3', 'BIRC5', 'BRCA2', 'BUB1', 'BUB3', 'CASP8AP2',
       'CBX1', 'CCNA2', 'CCNB2', 'CCND1', 'CCNF', 'CCNT1', 'CDC20',
       'CDC25A', 'CDC25B', 'CDC27', 'CDC45', 'CDC6', 'CDC7', 'CDK1',
       'CDK4', 'CDKN1B', 'CDKN2C', 'CDKN3', 'CENPA', 'CENPE', 'CENPF',
       'CHAF1A', 'CHEK1', 'CHMP1A', 'CKS1B', 'CKS2', 'CTCF', 'CUL1',
       'CUL3', 'CUL4A', 'CUL5', 'DBF4', 'DDX39A', 'DKC1', 'DMD', 'DR1',
       'DTYMK', 'E2F1', 'E2F2', 'E2F3', 'E2F4', 'EFNA5', 'EGF', 'ESPL1',
       'EWSR1', 'EXO1', 'EZH2', 'FANCC', 'FBXO5', 'FOXN3', 'G3BP1',
       'GINS2', 'GSPT1', 'H2AX', 'H2AZ1', 'H2AZ2', 'H2BC12', 'HIF1A',
       'HIRA', 'HMGA1', 'HMGB3', 'HMGN2', 'HMMR', 'HNRNPD', 'HNRNPU',
       'HOXC10', 'HSPA8', 'HUS1', 'ILF3', 'INCENP', 'JPT1', 'KATNA1',
       'KIF11', 'KIF15', 'KIF20B', 'KIF22', 'KIF23', 'KIF2C', 'KIF4A',
       'KIF5B', 'KMT5A', 'KNL1', 'KPNA2', 'KPNB1', 'LBR', 'LIG3', 'LMNB1',
       'MAD2L1', 'MAP3K20', 'MAPK14', 'MARCKS', 'MCM2', 'MCM3', 'MCM5',
       'MCM6', 'MEIS1', 'MEIS2', 'MKI67', 'MNAT1', 'MT2A', 'MTF2',
       'MYBL2', 'MYC', 'NASP', 'NCL', 'NDC80', 'NEK2', 'NOLC1', 'NOTCH2',
       'NSD2', 'NUMA1', 'NUP50', 'NUP98', 'NUSAP1', 'ODC1', 'ODF2',
       'ORC5', 'ORC6', 'PAFAH1B1', 'PBK', 'PDS5B', 'PLK1', 'PLK4', 'PML',
       'POLA2', 'POLE', 'POLQ', 'PRC1', 'PRIM2', 'PRMT5', 'PRPF4B',
       'PTTG1', 'PTTG3P', 'PURA', 'RACGAP1', 'RAD21', 'RAD23B', 'RAD54L',
       'RASAL2', 'RBL1', 'RBM14', 'RPA2', 'RPS6KA5', 'SAP30', 'SFPQ',
       'SLC12A2', 'SLC38A1', 'SLC7A1', 'SLC7A5', 'SMAD3', 'SMARCC1',
       'SMC1A', 'SMC2', 'SMC4', 'SNRPD1', 'SQLE', 'SRSF1', 'SRSF10',
       'SRSF2', 'SS18', 'STAG1', 'STIL', 'STMN1', 'SUV39H1', 'SYNCRIP',
       'TACC3', 'TENT4A', 'TFDP1', 'TGFB1', 'TLE3', 'TMPO', 'TNPO2',
       'TOP1', 'TOP2A', 'TPX2', 'TRA2B', 'TRAIP', 'TROAP', 'TTK', 'UBE2C',
       'UBE2S', 'UCK2', 'UPF1', 'WRN', 'XPO1', 'YTHDC1']

# %% [markdown]
# ### Load sample

# %%
sample = "Sample_HCC70_N703"
new_sample_name = "HCC70"
quant_params = "trimmed-reads-cutadapt-all/decoys-k19-1.4.0/customWh-top-3000"
genref = "human/assembly__GRCh38-hg38/annotation__gencode/gencode_34"
project = "dsp992"
cell_line = "HCC70"

# %%
sc = rnaseq.readwrite.read_raw(project_id  = project, quant_tool = "alevin", samples = sample, genes_id = "ensembl_gene_id", quant_params = quant_params, genref = genref, cdna = "3' tag", exp = "sc")
sc._inplace_subset_obs(np.argsort(sc.obs["raw_cb_freq"].values)[::-1][:3000])
sc.obs_names = sc.obs["CB"].tolist()
# Out:
# /home/arion/davidm/Data/datasets/raw/private/RNA-seq/sc/dsp992/quant/alevin/human/assembly__GRCh38-hg38/annotation__gencode/gencode_34/trimmed-reads-cutadapt-all/decoys-k19-1.4.0/customWh-top-3000
# Using BioMart Ensembl Genes 100 hsapiens_gene_ensembl for gene annotations.

# %%
rnaseq.setup.annotate_samples(sc, samples_annot_name = "samples", samples_annot = new_sample_name, ow = True)
rnaseq.setup.annotate_samples(sc, samples_annot_name = "cell_line", samples_annot = cell_line, ow = True)

rnaseq.setup.annotate_samples(sc, samples_annot_name = "total_UMIs", samples_annot = sc.X.toarray().sum(1).ravel())
rnaseq.setup.annotate_samples(sc, samples_annot_name = "#_genes", samples_annot = (sc.X.toarray() != 0).sum(1).ravel())
rnaseq.setup.annotate_samples(sc, samples_annot_name = "max_corr")
rnaseq.setup.annotate_samples(sc, samples_annot_name = "mt_frac")
rnaseq.setup.annotate_samples(sc, samples_annot_name = "rp_frac")

rnaseq.setup.annotate_genes(sc, "gene_biotype")
# Out:
# Annotating samples...
# Annotating cell_line...
# Annotating total_UMIs...
# Annotating #_genes...
# Annotating max_corr...
# Normalization by total UMIs...
# Log2 + 1 tranformation...
# Annotating mt_frac...
# Annotating chromosome_name using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...
# Annotating rp_frac...
# Annotating external_gene_name using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...
# Annotating gene_biotype using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...

# %%
sc._inplace_subset_obs(sc.obs["total_UMIs"] > 10)

# %%
sc.X.shape
# Out:
# (2841, 60240)

# %%
# x = sc.layers["raw"].toarray()[:, (sc.var["gene_biotype"] == "lncRNA") & (sc.var["external_gene_name"] != "MALAT1")]
x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "lncRNA"]
sc.obs["lncRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "rRNA"]
sc.obs["rRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "Mt_rRNA"]
sc.obs["Mt_rRNA"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "protein_coding"]
sc.obs["protein_coding"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, sc.var["gene_biotype"] == "processed_pseudogene"]
sc.obs["processed_pseudogene"] = x.sum(1) / sc.obs["total_UMIs"]

x = sc.layers["raw"].toarray()[:, [g.startswith("HSP") for g in sc.var["external_gene_name"]]]
sc.obs["hsp_frac"] = x.sum(1) / sc.obs["total_UMIs"]

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)

sc.var_names = sc.var["external_gene_name"].values
sc.var_names = np.array(sc.var_names.values)
sc.var_names_make_unique()
scanpy.tl.score_genes_cell_cycle(sc, s_genes=s_genes, g2m_genes=g2m_genes)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc_copy = sc.copy()

# %% [markdown]
# ### QC distributions

# %%
sc = sc_copy.copy()

# %%
plt.boxplot(sc.obs["total_UMIs"]);

# %%
plt.boxplot(sc.obs["max_corr"]);

# %%
_,ax = plt.subplots(figsize=(2.5,2))
rnaseq.plotting.loghist(sc.obs["total_UMIs"], bins=20, ax=ax, linewidth=0.1, edgecolor='black', fc = "white");
# ax.set_xlim(200,25000)
plt.axvline(1700, linewidth = 0.8, c = 'red')
plt.title(new_sample_name)
plt.ylabel("Fréquence")
plt.xlabel("Nombre de UMI")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Nombre de UMI')

# %%
_,ax = plt.subplots(figsize=(2.5,2))
plt.hist(sc.obs["max_corr"], bins=20, linewidth=0.1, edgecolor='black', fc = "white");
plt.title(new_sample_name)
plt.axvline(0.7, linewidth = 0.8, c = 'red')
plt.ylabel("Fréquence")
plt.xlabel("Rmax")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Rmax')

# %%
_,ax = plt.subplots(figsize=(2.5,2))
plt.hist(sc.obs["Mt_rRNA"], bins=20, linewidth=0.1, edgecolor='black', fc = "white");
plt.title(new_sample_name)
plt.axvline(0.03, linewidth = 0.8, c = 'red')
plt.ylabel("Fréquence")
plt.xlabel("Fraction de Mt_rRNA")
# plt.savefig(f"./figs/{prefix}_knee3.pdf");
# Out:
# Text(0.5, 0, 'Fraction de Mt_rRNA')

# %% [markdown]
# ### Explore sample

# %%
sc = sc_copy.copy()

# %%
metrics = ['total_UMIs', '#_genes', 'max_corr', 'MappingRate','DedupRate', 'mt_frac', 'rp_frac']
powers_metrics = [0.1,0.3,0.8,1.3,1.5,0.5,1.2]

biotypes = ['rRNA', 'Mt_rRNA', 'lncRNA', 'processed_pseudogene', 'protein_coding', 'G2M_score', 'hsp_frac', 'marker']
powers_biotypes = [1,0.5,1,0.5,1.8,0.5, 0.5, 1]

# %%
rnaseq.pp.log_norm(sc, plot=False, inplace=True, ow = True, verbose = True)
scanpy.pp.pca(sc, n_comps=50)
scanpy.pp.neighbors(sc, n_pcs=20, n_neighbors=15)
scanpy.tl.umap(sc, n_components=2)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc.obs["marker"] = sc.X.toarray()[:, sc.var["external_gene_name"].values == "VIM"] # HSPA5 SERP1

# %%
scatt = plt.subplots(figsize=(10,2.5), sharey=True)
for i,(c,p) in enumerate(zip(biotypes,powers_biotypes)):
    axi = plt.subplot(2,9,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 2, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(biotypes):
    axi = plt.subplot(2,9,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    plt.hist(sc.obs[c],  bins = 20, color="white", edgecolor="gray", linewidth = 0.3);

# %%
scatt = plt.subplots(figsize=(9.5,2.5), sharey=True)
for i,(c,p) in enumerate(zip(metrics,powers_metrics)):
    axi = plt.subplot(2,8,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 1.5, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(metrics):
    axi = plt.subplot(2,8,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    if c in ["total_UMIs", "#_genes"] :
        rnaseq.plotting.loghist(sc.obs[c], bins=20, ax=axi, linewidth=0.3, color="white", edgecolor="gray");
    else :
        plt.hist(sc.obs[c],  bins = 15, color="white", edgecolor="gray", linewidth = 0.3);

# %% [markdown]
# ### Filter sample

# %%
sc = sc_copy.copy()

# %%
# sc._inplace_subset_obs(sc.obs_names[np.argsort(sc.obs["total_UMIs"])[:-50]])

# %%
sc._inplace_subset_obs(sc.obs["total_UMIs"] < 40000)
sc._inplace_subset_obs(sc.obs["total_UMIs"] > 3500)
# sc._inplace_subset_obs(sc.obs["lncRNA"] <0.04)

# %%
rnaseq.pp.log_norm(sc, plot=True, inplace=True, ow = True, verbose = True)
scanpy.pp.pca(sc, n_comps=50)
scanpy.pp.neighbors(sc, n_pcs=20, n_neighbors=15)
scanpy.tl.umap(sc, n_components=2)
# Out:
# Normalization by total UMIs...
# Log2 + 1 tranformation...

# %%
sc.obs["marker"] = sc.X.toarray()[:, sc.var["external_gene_name"].values == "BST2"] # BST2

# %%
scatt = plt.subplots(figsize=(10,2.5), sharey=True)
for i,(c,p) in enumerate(zip(biotypes,powers_biotypes)):
    axi = plt.subplot(2,9,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 2, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(biotypes):
    axi = plt.subplot(2,9,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    plt.hist(sc.obs[c],  bins = 20, color="white", edgecolor="gray", linewidth = 0.3);

# %%
scatt = plt.subplots(figsize=(9.5,2.5), sharey=True)
for i,(c,p) in enumerate(zip(metrics,powers_metrics)):
    axi = plt.subplot(2,8,i+1)
    plt.title(c)
    plt.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], c = sc.obs[c], s = 1.5, norm = PowerNorm(p))
    plt.axis('off')

for j,c in enumerate(metrics):
    axi = plt.subplot(2,8,i+j+3)
    axi.spines['right'].set_visible(False)
    axi.spines['top'].set_visible(False)
    axi.set_yticks([])
    if c in ["total_UMIs", "#_genes"] :
        rnaseq.plotting.loghist(sc.obs[c], bins=20, ax=axi, linewidth=0.3, color="white", edgecolor="gray");
    else :
        plt.hist(sc.obs[c],  bins = 15, color="white", edgecolor="gray", linewidth = 0.3);

# %%
sc.X.shape
# Out:
# (879, 60240)

# %% [markdown]
# ### Alevin comparison

# %%
quant_params_default = "trimmed-reads-cutadapt-all/decoys-k31-1.4.0/default"
whitelist_default = pd.read_table(f"/home/arion/davidm/Data/datasets/raw/private/RNA-seq/sc/{project}/quant/alevin/{genref}/{quant_params_default}/{sample}/alevin/whitelist.txt", header=None)
cbs_default = pd.read_table(f"/home/arion/davidm/Data/datasets/raw/private/RNA-seq/sc/{project}/quant/alevin/{genref}/{quant_params_default}/{sample}/alevin/quants_mat_rows.txt", header=None)

# %%
len(cbs_default)
# Out:
# 336

# %%
len(whitelist_default)
# Out:
# 105

# %%
scatt = plt.subplots(figsize=(2.5,2))

i = np.array([cb in whitelist_default[0].values for cb in sc.obs_names])
plt.scatter(sc.obsm["X_umap"][:,0][i], sc.obsm["X_umap"][:,1][i], linewidths=0.35, edgecolors = "black", \
            s = 10, vmin = -0.5, vmax = 1.5, color = "white")
plt.scatter(sc.obsm["X_umap"][:,0][~i], sc.obsm["X_umap"][:,1][~i],\
            s = 12, vmin = -0.5, vmax = 1.5, alpha=0.35, color = "indianred", edgecolors = "black", linewidths=0.1)

# %%
scatt = plt.subplots(figsize=(2.5,2))

i = np.array([cb in cbs_default[0].values for cb in sc.obs_names])
plt.scatter(sc.obsm["X_umap"][:,0][i], sc.obsm["X_umap"][:,1][i], linewidths=0.35, edgecolors = "black", \
            s = 10, vmin = -0.5, vmax = 1.5, color = "white")
plt.scatter(sc.obsm["X_umap"][:,0][~i], sc.obsm["X_umap"][:,1][~i],\
            s = 12, vmin = -0.5, vmax = 1.5, alpha=0.35, color = "indianred", edgecolors = "black", linewidths=0.1)

# %%
sc.obs["alevin"] = np.array([cb in cbs_default.values for cb in sc.obs_names]).astype(int).astype(str)

# %%
sc.var_names = sc.var["external_gene_name"].values
scanpy.tl.rank_genes_groups(sc, groupby="alevin", n_genes=len(sc.var_names),rankby_abs=True, method="wilcoxon")
# Out:
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'samples' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'project_id' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cell_line' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'phase' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'alevin' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromosome_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'external_gene_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_biotype' as categorical

# %%
rnaseq.dea.volcano_plot(sc, group="0", top=20, show_genes='up')

# %% [markdown]
# ### Save filtered data

# %%
rnaseq.readwrite.write_filtered(sc)
# Out:
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'samples' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'project_id' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cell_line' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'phase' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromosome_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'external_gene_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_biotype' as categorical

# %%
del sc, sc_copy

# %% [markdown]
# ### Heterogeneity analysis

# %%
scanpy.tl.leiden(sc, resolution=0.5)

scatt,_ = plt.subplots(figsize=(3,2))

rnaseq.plotting.scatter(sc.obsm["X_umap"][:,0], sc.obsm["X_umap"][:,1], color = sc.obs["leiden"], \
    s = 20, xlabel="UMAP1", ylabel="UMAP2", color_title = "clusters",\
    title = new_sample_name, linewidth=0.15, fig = scatt)

# %%
rnaseq.setup.annotate_genes(sc, 'description')
# Out:
# Annotating description using Biomart (Ensembl Genes 100, 'hsapiens_gene_ensembl')...

# %%
gene_exp = pd.DataFrame(sc.X.toarray().T, columns = sc.obs["CB"].values)
class_vector = (sc.obs["leiden"].values == '2').astype(str)
class_vector = np.where(class_vector == 'True', "cluster", class_vector) 
class_vector = np.where(class_vector == 'False', "rest", class_vector)

# %%
idx = np.argsort(class_vector)
gene_exp = gene_exp[gene_exp.columns[idx]]
gene_exp.insert(0, "DESCRIPTION", sc.var["description"].values, True)
gene_exp.insert(0, "NAME", sc.var["external_gene_name"].values, True)

class_vector = list(class_vector[idx])

# %%
gs_res = gp.gsea(gene_exp, # ordata='./P53_resampling_data.txt'
                 'MSigDB_Hallmark_2020', # enrichr library names
                  class_vector,
                 # set permutation_type to phenotype if samples >=15
                 permutation_type='phenotype',
                 permutation_num=100, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 method='signal_to_noise',
                 processes=4, seed= 7,
                 format='png')
# Out:
# 2021-12-16 07:18:47,489 Warning: dropping duplicated gene names, only keep the first values

# %%
res = gs_res.res2d.sort_values(by='nes', ascending=False)
res = res.loc[res.index[(res['fdr'].values < 0.05) & (res['pval'].values < 0.05)]]

# %%
res
# Out:
#                                          es       nes  pval       fdr  \
# Term
# DNA Repair                         0.642756  3.243183   0.0  0.000000
# Oxidative Phosphorylation          0.782082  3.163334   0.0  0.000000
# Adipogenesis                       0.648666  3.144683   0.0  0.000000
# Protein Secretion                  0.674692  3.038803   0.0  0.000000
# mTORC1 Signaling                   0.629098  3.031573   0.0  0.000000
# Xenobiotic Metabolism              0.550622  2.990809   0.0  0.000000
# Fatty Acid Metabolism              0.654067  2.980690   0.0  0.000000
# Glycolysis                         0.601280  2.905849   0.0  0.000000
# Pperoxisome                        0.623148  2.895745   0.0  0.000000
# Reactive Oxygen Species Pathway    0.752911  2.893472   0.0  0.000000
# Myc Targets V1                     0.639836  2.860155   0.0  0.000000
# Apoptosis                          0.566325  2.801354   0.0  0.000000
# Cholesterol Homeostasis            0.620610  2.775403   0.0  0.000000
# Complement                         0.496085  2.728681   0.0  0.000000
# Estrogen Response Late             0.488617  2.597508   0.0  0.000000
# E2F Targets                        0.559241  2.579301   0.0  0.000000
# Hypoxia                            0.497798  2.523493   0.0  0.000000
# heme Metabolism                    0.457754  2.467846   0.0  0.000000
# Androgen Response                  0.570416  2.464760   0.0  0.000000
# Interferon Gamma Response          0.521232  2.461356   0.0  0.000000
# Unfolded Protein Response          0.511384  2.416243   0.0  0.000000
# Epithelial Mesenchymal Transition  0.453421  2.405707   0.0  0.000000
# Spermatogenesis                    0.540555  2.392915   0.0  0.000000
# UV Response Up                     0.465262  2.355457   0.0  0.000000
# Bile Acid Metabolism               0.517374  2.264507   0.0  0.000000
# Inflammatory Response              0.468741  2.249502   0.0  0.000000
# Coagulation                        0.493372  2.232586   0.0  0.000000
# p53 Pathway                        0.404869  2.187577   0.0  0.000000
# Allograft Rejection                0.455464  2.171882   0.0  0.000000
# Interferon Alpha Response          0.522216  2.126547   0.0  0.000000
# TNF-alpha Signaling via NF-kB      0.448322  2.085147   0.0  0.000000
# IL-6/JAK/STAT3 Signaling           0.480966  2.058648   0.0  0.000000
# KRAS Signaling Up                  0.382786  2.033013   0.0  0.000000
# UV Response Dn                     0.398896  1.990088   0.0  0.000000
# Apical Junction                    0.385167  1.969920   0.0  0.000000
# IL-2/STAT5 Signaling               0.372439  1.950066   0.0  0.000000
# PI3K/AKT/mTOR  Signaling           0.430735  1.884882   0.0  0.000000
# Pancreas Beta Cells                0.625481  1.876831   0.0  0.000000
# Myc Targets V2                     0.450065  1.768760   0.0  0.003060
# Estrogen Response Early            0.337023  1.745689   0.0  0.003978
# Angiogenesis                       0.474637  1.563187   0.0  0.025571
#
#                                    geneset_size  matched_size  \
# Term
# DNA Repair                                  150           149
# Oxidative Phosphorylation                   200           199
# Adipogenesis                                200           181
# Protein Secretion                            96            94
# mTORC1 Signaling                            200           196
# Xenobiotic Metabolism                       200           153
# Fatty Acid Metabolism                       158           133
# Glycolysis                                  200           183
# Pperoxisome                                 104            88
# Reactive Oxygen Species Pathway              49            44
# Myc Targets V1                              200           200
# Apoptosis                                   161           142
# Cholesterol Homeostasis                      74            71
# Complement                                  200           152
# Estrogen Response Late                      200           165
# E2F Targets                                 200           200
# Hypoxia                                     200           177
# heme Metabolism                             200           166
# Androgen Response                           100            94
# Interferon Gamma Response                   200           165
# Unfolded Protein Response                   113           113
# Epithelial Mesenchymal Transition           200           175
# Spermatogenesis                             135            78
# UV Response Up                              158           148
# Bile Acid Metabolism                        112            79
# Inflammatory Response                       200           135
# Coagulation                                 138            92
# p53 Pathway                                 200           187
# Allograft Rejection                         200           116
# Interferon Alpha Response                    97            91
# TNF-alpha Signaling via NF-kB               200           189
# IL-6/JAK/STAT3 Signaling                     87            64
# KRAS Signaling Up                           200           151
# UV Response Dn                              144           137
# Apical Junction                             200           156
# IL-2/STAT5 Signaling                        199           156
# PI3K/AKT/mTOR  Signaling                    105            96
# Pancreas Beta Cells                          40            21
# Myc Targets V2                               58            57
# Estrogen Response Early                     200           181
# Angiogenesis                                 36            27
#
#                                                                                genes  \
# Term
# DNA Repair                         MPC2;POLR2J;PCNA;POLR2G;GTF2A2;TYMS;DAD1;NME1;...
# Oxidative Phosphorylation          MDH1;NDUFB4;UQCRH;ATP5F1C;SLC25A5;NDUFA4;NDUFV...
# Adipogenesis                       COX7B;SDHB;CYC1;MGST3;ALDOA;ATP5PO;MTCH2;ACAA2...
# Protein Secretion                  SNX2;ARF1;SOD1;KRT18;BNIP3;RAB2A;TMED10;GLA;CT...
# mTORC1 Signaling                   GAPDH;TPI1;LDHA;PSMA3;HSPE1;ALDOA;PGK1;ATP6V1D...
# Xenobiotic Metabolism              NQO1;CYB5A;ACP1;CBR1;HPRT1;GSTO1;BLVRB;ECH1;NI...
# Fatty Acid Metabolism              MDH1;H2AZ1;MIF;PCBD1;LDHA;ALDOA;SDHD;OSTC;ACAA...
# Glycolysis                         MDH1;MIF;TPI1;LDHA;ALDOA;PGK1;CYB5A;PGAM1;SDHC...
# Pperoxisome                        ITGB1BP1;FDPS;GSTK1;SOD1;SCP2;ECH1;CDK7;PRDX1;...
# Reactive Oxygen Species Pathway    NDUFB4;MGST1;PRDX4;NQO1;TXN;SOD1;PRDX2;GLRX;LA...
# Myc Targets V1                     H2AZ1;RPS5;PSMD8;PRDX4;RAN;LDHA;PSMA2;RPLP0;PS...
# Apoptosis                          ANXA1;VDAC2;TNFRSF12A;LGALS3;IFITM3;SOD1;CAV1;...
# Cholesterol Homeostasis            S100A11;TNFRSF12A;LGALS3;FDPS;ECH1;ACAT2;FDFT1...
# Complement                         LGALS3;PFN1;CD59;IL6;CTSC;TFPI2;CALM1;CD46;CAS...
# Estrogen Response Late             RNASEH2A;PERP;HPRT1;CAV1;BLVRB;FDFT1;GLA;ARL3;...
# E2F Targets                        H2AZ1;PRDX4;RAN;EXOSC8;PCNA;RNASEH2A;UBE2T;CKS...
# Hypoxia                            GAPDH;MIF;TPI1;LDHA;ALDOA;PGK1;ANXA2;FAM162A;C...
# heme Metabolism                    MGST3;PSMD9;BLVRB;PRDX2;HTATIP2;HEBP1;ADIPOR1;...
# Androgen Response                  MYL12A;B2M;DBI;SRP19;VAPA;UBE2I;CENPN;TMEM50A;...
# Interferon Gamma Response          B2M;PSMA2;PSMB2;PSMA3;IFITM3;LGALS3BP;PSME1;IL...
# Unfolded Protein Response          SPCS1;NHP2;EIF4A1;CKS1B;EIF4A3;SEC11A;EIF4EBP1...
# Epithelial Mesenchymal Transition  TNFRSF12A;DKK1;LGALS1;CD59;IL6;PPIB;ITGB1;VIM;...
# Spermatogenesis                    PEBP1;CDKN3;PSMG1;VDAC3;PARP2;ZC3H14;RFC4;NCAP...
# UV Response Up                     ALDOA;GGH;IL6;ATP6V1F;PARP2;SIGMAR1;BID;EIF5;T...
# Bile Acid Metabolism               GSTK1;SOD1;SCP2;IDH2;AMACR;PHYH;CAT;PEX13;PNPL...
# Inflammatory Response              IL1B;IL6;SRI;CXCL8;ADM;ADORA2B;IL7R;NFKBIA;BDK...
# Coagulation                        ANXA1;TFPI2;ARF4;ISCU;PEF1;CD9;CTSB;DPP4;GNG12...
# p53 Pathway                        TPRKB;PCNA;HINT1;PERP;FAM162A;LDHB;NINJ1;RAD51...
# Allograft Rejection                B2M;CD47;NME1;IL1B;IL6;RPS3A;UBE2N;MRPL3;DEGS1...
# Interferon Alpha Response          B2M;PSMA3;IFITM3;CD47;LGALS3BP;PSME1;HLA-C;MVB...
# TNF-alpha Signaling via NF-kB      EIF1;IL1B;IL6;NINJ1;TANK;SAT1;PHLDA2;IL7R;NFKB...
# IL-6/JAK/STAT3 Signaling           TNFRSF12A;IL1B;HAX1;IL6;CD9;PTPN1;CXCL1;IRF1;I...
# KRAS Signaling Up                  PRELID3B;IL1B;GLRX;IL7R;ALDH1A3;PSMB8;CCL20;PL...
# UV Response Dn                     ANXA2;CAV1;SRI;ANXA4;PTEN;ADORA2B;MRPS31;DUSP1...
# Apical Junction                    MYL12B;ARPC2;PFN1;TUBG1;RSU1;ITGB1;PTEN;CD99;G...
# IL-2/STAT5 Signaling               IFITM3;GSTO1;ANXA4;GPX4;COCH;PLSCR1;SYNGR2;AMA...
# PI3K/AKT/mTOR  Signaling           ARPC3;ARF1;CFL1;PFN1;UBE2N;PPP1CA;CALR;PTEN;UB...
# Pancreas Beta Cells                SPCS1;SRP14;SRP9;SEC11A;DPP4;ELP4;PAX6;AKT3;IS...
# Myc Targets V2                     HSPE1;NDUFAF4;AIMP2;RABEPK;NOP16;SORD;CDK4;PHB...
# Estrogen Response Early            KRT18;BLVRB;FDFT1;GLA;ARL3;DYNLT3;SNX24;PLAAT3...
# Angiogenesis                       PTK2;LRPAP1;FSTL1;TIMP1;APP;OLR1;STC1;FGFR1;IT...
#
#                                                                          ledge_genes
# Term
# DNA Repair                         MPC2;POLR2J;PCNA;POLR2G;GTF2A2;TYMS;DAD1;NME1;...
# Oxidative Phosphorylation          MDH1;NDUFB4;UQCRH;ATP5F1C;SLC25A5;NDUFA4;NDUFV...
# Adipogenesis                       COX7B;SDHB;CYC1;MGST3;ALDOA;ATP5PO;MTCH2;ACAA2...
# Protein Secretion                  SNX2;ARF1;SOD1;KRT18;BNIP3;RAB2A;TMED10;GLA;CT...
# mTORC1 Signaling                   GAPDH;TPI1;LDHA;PSMA3;HSPE1;ALDOA;PGK1;ATP6V1D...
# Xenobiotic Metabolism              NQO1;CYB5A;ACP1;CBR1;HPRT1;GSTO1;BLVRB;ECH1;NI...
# Fatty Acid Metabolism              MDH1;H2AZ1;MIF;PCBD1;LDHA;ALDOA;SDHD;OSTC;ACAA...
# Glycolysis                         MDH1;MIF;TPI1;LDHA;ALDOA;PGK1;CYB5A;PGAM1;SDHC...
# Pperoxisome                        ITGB1BP1;FDPS;GSTK1;SOD1;SCP2;ECH1;CDK7;PRDX1;...
# Reactive Oxygen Species Pathway    NDUFB4;MGST1;PRDX4;NQO1;TXN;SOD1;PRDX2;GLRX;LA...
# Myc Targets V1                     H2AZ1;RPS5;PSMD8;PRDX4;RAN;LDHA;PSMA2;RPLP0;PS...
# Apoptosis                          ANXA1;VDAC2;TNFRSF12A;LGALS3;IFITM3;SOD1;CAV1;...
# Cholesterol Homeostasis            S100A11;TNFRSF12A;LGALS3;FDPS;ECH1;ACAT2;FDFT1...
# Complement                         LGALS3;PFN1;CD59;IL6;CTSC;TFPI2;CALM1;CD46;CAS...
# Estrogen Response Late             RNASEH2A;PERP;HPRT1;CAV1;BLVRB;FDFT1;GLA;ARL3;...
# E2F Targets                        H2AZ1;PRDX4;RAN;EXOSC8;PCNA;RNASEH2A;UBE2T;CKS...
# Hypoxia                            GAPDH;MIF;TPI1;LDHA;ALDOA;PGK1;ANXA2;FAM162A;C...
# heme Metabolism                    MGST3;PSMD9;BLVRB;PRDX2;HTATIP2;HEBP1;ADIPOR1;...
# Androgen Response                  MYL12A;B2M;DBI;SRP19;VAPA;UBE2I;CENPN;TMEM50A;...
# Interferon Gamma Response          B2M;PSMA2;PSMB2;PSMA3;IFITM3;LGALS3BP;PSME1;IL...
# Unfolded Protein Response          SPCS1;NHP2;EIF4A1;CKS1B;EIF4A3;SEC11A;EIF4EBP1...
# Epithelial Mesenchymal Transition  TNFRSF12A;DKK1;LGALS1;CD59;IL6;PPIB;ITGB1;VIM;...
# Spermatogenesis                    PEBP1;CDKN3;PSMG1;VDAC3;PARP2;ZC3H14;RFC4;NCAP...
# UV Response Up                     ALDOA;GGH;IL6;ATP6V1F;PARP2;SIGMAR1;BID;EIF5;T...
# Bile Acid Metabolism               GSTK1;SOD1;SCP2;IDH2;AMACR;PHYH;CAT;PEX13;PNPL...
# Inflammatory Response              IL1B;IL6;SRI;CXCL8;ADM;ADORA2B;IL7R;NFKBIA;BDK...
# Coagulation                        ANXA1;TFPI2;ARF4;ISCU;PEF1;CD9;CTSB;DPP4;GNG12...
# p53 Pathway                        TPRKB;PCNA;HINT1;PERP;FAM162A;LDHB;NINJ1;RAD51...
# Allograft Rejection                B2M;CD47;NME1;IL1B;IL6;RPS3A;UBE2N;MRPL3;DEGS1...
# Interferon Alpha Response          B2M;PSMA3;IFITM3;CD47;LGALS3BP;PSME1;HLA-C;MVB...
# TNF-alpha Signaling via NF-kB      EIF1;IL1B;IL6;NINJ1;TANK;SAT1;PHLDA2;IL7R;NFKB...
# IL-6/JAK/STAT3 Signaling           TNFRSF12A;IL1B;HAX1;IL6;CD9;PTPN1;CXCL1;IRF1;I...
# KRAS Signaling Up                  PRELID3B;IL1B;GLRX;IL7R;ALDH1A3;PSMB8;CCL20;PL...
# UV Response Dn                     ANXA2;CAV1;SRI;ANXA4;PTEN;ADORA2B;MRPS31;DUSP1...
# Apical Junction                    MYL12B;ARPC2;PFN1;TUBG1;RSU1;ITGB1;PTEN;CD99;G...
# IL-2/STAT5 Signaling               IFITM3;GSTO1;ANXA4;GPX4;COCH;PLSCR1;SYNGR2;AMA...
# PI3K/AKT/mTOR  Signaling           ARPC3;ARF1;CFL1;PFN1;UBE2N;PPP1CA;CALR;PTEN;UB...
# Pancreas Beta Cells                                     SPCS1;SRP14;SRP9;SEC11A;DPP4
# Myc Targets V2                     HSPE1;NDUFAF4;AIMP2;RABEPK;NOP16;SORD;CDK4;PHB...
# Estrogen Response Early            KRT18;BLVRB;FDFT1;GLA;ARL3;DYNLT3;SNX24;PLAAT3...
# Angiogenesis                                   PTK2;LRPAP1;FSTL1;TIMP1;APP;OLR1;STC1

# %%
sc.var_names = sc.var["external_gene_name"].values
scanpy.tl.rank_genes_groups(sc, groupby="leiden", n_genes=len(sc.var_names),rankby_abs=True, method="wilcoxon")
# Out:
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'samples' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'project_id' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'phase' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromosome_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'external_gene_name' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_biotype' as categorical
# /u/davidm/VirtualEns/python_3.9.5/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'description' as categorical

# %%
rnaseq.dea.volcano_plot(sc, group="2", top=50)

# %%
rnaseq.dea.enrichr(sc, group='2', libraries="MSigDB_Hallmark_2020")
# Out:
# /u/davidm/Documents/Master-thesis/Scripts/RNA-seq/python/rnaseq/dea.py:38: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = pd.DataFrame(np.array(data[gene_set_library])[:,1:], columns=["Term", "P-value", "Z-score", "Combined Score", "Genes", "Adjusted P-value", "Old P-value", "Old adjusted P-value"])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>Term</th>
#       <th>P-value</th>
#       <th>Z-score</th>
#       <th>Combined Score</th>
#       <th>Genes</th>
#       <th>Adjusted P-value</th>
#       <th>Old P-value</th>
#       <th>Old adjusted P-value</th>
#       <th>color</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Oxidative Phosphorylation</td>
#       <td>0.0</td>
#       <td>6.562704</td>
#       <td>528.178403</td>
#       <td>[ISCA1, MTRR, ACAA2, COX6A1, PHB2, MTRF1, MPC1, PMPCA, ATP6V1E1, ACAA1, ATP6V1G1, CPT1A, PHYH, ATP6V0E1, ECH1, SDHC, SDHD, ATP1B1, SDHB, OXA1L, COX7A2L, POR, FDX1, VDAC3, VDAC2, UQCRC2, ISCU, RETSAT, UQCRB, ABCB7, COX15, MGST3, ATP5MC2, ATP5MC3, HTRA2, COX7A2, MRPL15, UQCRH, MRPL11, ATP5MC1, ACAT1, TIMM50, PRDX3, LDHB, LDHA, CYB5R3, RHOT1, GRPEL1, ATP6V1H, COX11, CYC1, NDUFV2, ATP6V1D, ATP6V1C1, ATP5MF, COX10, DECR1, ATP6V1F, SURF1, PDHA1, IDH1, IDH2, GOT2, CS, GLUD1, CYCS, ACO2, COX7B, MRPS15, SLC25A3, ALAS1, MRPS11, MRPS12, HCCS, ETFA, TCIRG1, MRPL34, MRPL35, CASP7, OPA1, NNT, IDH3B, TIMM17A, UQCRFS1, ACADM, DLAT, IDH3A, COX8A, BCKDHA, GPX4, MRPS22, NDUFC2, NDUFC1, HADHB, SUPV3L1, HADHA, BDH2, NDUFS8, NDUFS7, NDUFS6, ...]</td>
#       <td>-33.253845</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>mTORC1 Signaling</td>
#       <td>0.0</td>
#       <td>4.690078</td>
#       <td>273.275721</td>
#       <td>[TES, PITPNB, UBE2D3, PLOD2, TMEM97, ENO1, IFI30, RRP9, FADS2, PNP, TBK1, NAMPT, PSPH, PDK1, MAP2K3, STARD4, G6PD, IFRD1, TUBA4A, CDC25A, ACLY, DDX39A, PPA1, DDIT3, PSME3, MTHFD2L, HMBS, TRIB3, HPRT1, PPIA, SKAP2, IDI1, NUP205, PSMD12, FKBP2, INSIG1, GMPS, STC1, AK4, SLC1A5, ACACA, HSP90B1, ATP5MC1, SLC9A3R1, LDHA, EBP, RDH11, PRDX1, SERPINH1, PGK1, SSR1, LTA4H, ATP6V1D, XBP1, SDF2L1, GOT1, PNO1, SRD5A1, EDEM1, IDH1, PLK1, EIF2S2, DHFR, MLLT11, CCT6A, QDPR, SLC6A6, GCLC, COPS5, EPRS1, P4HA1, BHLHE40, NMT1, PSMG1, CALR, DHCR7, LGMN, NFKBIB, GSK3B, GBE1, SLC2A1, HK2, SERP1, ME1, SLC37A4, CTSC, PGM1, TPI1, HMGCS1, ELOVL5, SORD, ELOVL6, TUBG1, UCHL5, PSMA3, PSMA4, ETF1, ALDOA, EEF1E1, GAPDH, ...]</td>
#       <td>-23.906999</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Protein Secretion</td>
#       <td>0.0</td>
#       <td>8.656225</td>
#       <td>419.930678</td>
#       <td>[ARF1, SNAP23, ICA1, CLTA, RAB22A, RPS6KA3, GOLGA4, AP1G1, LAMP2, KIF1B, ARFIP1, AP3S1, AP2M1, CTSC, RAB2A, TPD52, STX7, COG2, ADAM10, AP3B1, SCAMP1, ARFGAP3, SCAMP3, TOM1L1, VAMP7, RER1, TMX1, ZW10, ERGIC3, VAMP4, SEC22B, VAMP3, NAPA, COPB2, STX12, CD63, TMED10, TSG101, SGMS1, STX16, COPB1, VPS4B, GOSR2, USO1, ATP1A1, CLCN3, EGFR, NAPG, CLN5, LMAN1, SNX2, AP2S1, ATP6V1H, MAPK1, YKT6, SEC31A, ARFGEF1, ABCA1, ARFGEF2, CAV2, BNIP3, AP2B1, STAM, ARCN1, SOD1, KRT18, RAB14, PPT1, GNAS, YIPF6, RAB9A, VPS45, SEC24D, PAM, RAB5A, GLA, COPE, BET1]</td>
#       <td>-19.846640</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>DNA Repair</td>
#       <td>0.0</td>
#       <td>4.670548</td>
#       <td>205.882767</td>
#       <td>[CDA, ARL6IP1, MPG, GTF2B, PNP, CLP1, MPC2, LIG1, GTF2F1, RBX1, BOLA2, HPRT1, SRSF6, EIF1B, CCNO, POM121, TSG101, CSTF3, AK1, SUPT4H1, AK3, AAAS, SDCBP, DGUOK, ZNF707, SURF1, POLR3GL, SMAD5, ZWINT, POLA1, POLA2, ADA, GSDME, FEN1, SNAPC5, POLB, ZNRD1, MRPL40, GUK1, REV3L, ELOA, NELFCD, NELFE, RFC5, RFC3, RFC4, GPX4, NCBP2, RFC2, NME4, VPS37B, DDB2, NME1, APRT, NT5C3A, RRM2B, DAD1, NFX1, POLR1C, POLR1D, UMPS, GTF2A2, RALA, PCNA, CANT1, GTF3C5, PRIM1, USP11, GMPR2, DCTN4, TAF9, TYMS, POLD3, NT5C, POLD4, POLR2C, POLR2D, POLR2E, POLR2G, POLR2H, STX3, POLR2I, POLR2J, RAE1, POLR2K, DUT, BRF2, TAF12, TAF10, ADRM1, RPA2, GTF2H1, SSRP1, TARBP2, NUDT9, RAD52, NUDT21, RAD51, ERCC3, POLR3C, ...]</td>
#       <td>-18.047257</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>Myc Targets V1</td>
#       <td>0.0</td>
#       <td>3.411605</td>
#       <td>132.521617</td>
#       <td>[EIF4A1, HDDC2, RPL34, HNRNPU, PWP1, PHB2, RPL6, UBE2L3, RRP9, PSMD8, EEF1B2, SNRPD2, RUVBL2, PSMD3, SNRPD3, KPNA2, RPS10, EIF1AX, RPS5, IFRD1, RPS6, UBE2E1, CLNS1A, VDAC3, SRSF2, SNRPG, NHP2, ERH, HPRT1, PPIA, SRSF7, SNRPA, KPNB1, SET, CSTF2, CUL1, PRDX3, LDHA, PRDX4, PCBP1, ORC2, PGK1, CYC1, NOP16, CBX3, GOT2, PA2G4, MRPL23, EIF2S2, EIF2S1, SRPK1, LSM2, AIMP2, COPS5, EPRS1, CDK4, CDK2, YWHAE, SLC25A3, RPLP0, SYNCRIP, YWHAQ, C1QBP, AP3S1, MRPL9, ACP1, CCT2, RFC4, NCBP1, VBP1, NCBP2, PABPC4, CAD, CTPS1, NME1, CCNA2, PSMA6, PSMA4, PSMA1, PSMA2, SNRPA1, MCM5, ETF1, MCM6, MCM2, PRPS2, PCNA, SF3B3, SRSF1, DDX21, TYMS, COX5A, HSPD1, SRM, EXOSC7, CDC45, PSMB2, PSMB3, TRA2B, FAM120A, ...]</td>
#       <td>-15.869894</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>E2F Targets</td>
#       <td>0.0</td>
#       <td>3.267612</td>
#       <td>119.008799</td>
#       <td>[NUP107, POP7, MRE11, DSCC1, CCP110, CHEK2, CHEK1, STMN1, NBN, KPNA2, TIPIN, LIG1, HUS1, CDC25A, DDX39A, MELK, MSH2, CCNE1, ZW10, TIMELESS, SRSF2, ASF1A, ASF1B, SNRPB, SLBP, NUP205, RNASEH2A, CDCA3, SHMT1, AK2, CCNB2, PRDX4, ORC6, RACGAP1, UBR7, ORC2, PLK4, BARD1, PLK1, NUP153, PA2G4, PAICS, EIF2S1, POLA2, STAG1, NASP, CDK4, UBE2T, CDK1, CNOT9, MXD3, H2AX, CDKN1B, SUV39H1, BRCA1, CTCF, BRCA2, CKS1B, LMNB1, SYNCRIP, ING3, MYBL2, TK1, TCF19, HELLS, RFC3, EED, RFC2, TUBB, CTPS1, TUBG1, SMC1A, DCK, NME1, MMS22L, RAD51C, ESPL1, CKS2, MCM3, LUC7L3, MCM5, MCM6, DCTPP1, MCM2, PRIM2, PRPS1, PCNA, SRSF1, UNG, TBRG4, PSMC3IP, POLD3, TRA2B, EXOSC8, PPP1R8, POLD2, E2F8, GINS1, H2AZ1, DUT, ...]</td>
#       <td>-14.896503</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>Adipogenesis</td>
#       <td>0.0</td>
#       <td>3.001364</td>
#       <td>95.521083</td>
#       <td>[MTCH2, ACAA2, ITSN1, ARAF, GHITM, COX6A1, SCP2, HADH, PHYH, MCCC1, ECH1, TALDO1, ATP1B3, LIFR, SDHC, CMBL, SDHB, SLC5A6, ACLY, POR, GPD2, RAB34, PREB, CD151, RETSAT, MGST3, AK2, ABCB8, MRPL15, SLC1A5, C3, PRDX3, BCL2L13, GRPEL1, DHRS7B, G3BP2, CYC1, DECR1, ABCA1, ESRRA, IDH1, EPHX2, RMDN3, COQ9, DNAJC15, COQ5, CS, QDPR, COQ3, UCK1, REEP5, NMT1, PEMT, NABP1, ACO2, DHCR7, SLC25A1, COX7B, RNF11, SOWAHC, GBE1, CPT2, ALDH2, NKIRAS1, DBT, ME1, ACADM, DLAT, ACADS, PGM1, HIBCH, IDH3A, COX8A, BCKDHA, JAGN1, GPX4, CHUK, IFNGR1, ELOVL6, ARL4A, ACOX1, CAT, NDUFS3, PPARG, PLIN2, CD302, ALDOA, DLD, MGLL, PPP1R15B, ECHS1, SLC66A3, LAMA4, ATL2, UQCR10, TANK, TOB1, AGPAT3, SAMM50, GPAT4, ...]</td>
#       <td>-12.967937</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>Glycolysis</td>
#       <td>0.0</td>
#       <td>2.76065</td>
#       <td>76.089413</td>
#       <td>[CHPF, PLOD2, ENO1, PLOD1, NSDHL, FAM162A, STMN1, PDK3, SOX9, IL13RA1, G6PD, COG2, TALDO1, SDHC, ALG1, MIF, TPST1, RRAGD, PKP2, KDELR3, KIF20A, RBCK1, ALDH7A1, PPIA, GNE, TSTA3, COPB2, PAXIP1, SDC2, STC1, AK3, AK4, TXN, ARPP19, LDHA, CHST12, STC2, PGK1, NDUFV3, ANKZF1, HOMER1, GOT1, IDH1, PMM2, GOT2, ECD, SRD5A3, EXT1, ISG20, EXT2, GCLC, P4HA1, COL5A1, NASP, P4HA2, CDK1, SDC1, TGFBI, PAM, GALK2, GALK1, PYGB, B4GALT1, CITED2, PYGL, HK2, HS2ST1, GMPPB, GYS1, CASP6, GMPPA, ME1, PGM2, PGLS, ME2, GUSB, SLC37A4, TPI1, PGAM1, AKR1A1, PKM, HAX1, KIF2A, ADORA2B, ALDOA, DLD, B4GALT7, MET, B4GALT4, SLC25A13, ALDH9A1, PRPS1, RPE, GLRX, EGFR, PPP2CB, NT5E, UGP2, GPC1, MXI1, ...]</td>
#       <td>-11.174205</td>
#       <td>0</td>
#       <td>0</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>Unfolded Protein Response</td>
#       <td>0.0</td>
#       <td>3.367219</td>
#       <td>75.502372</td>
#       <td>[EIF4A2, H2AX, EIF4A1, FKBP14, POP4, EIF4A3, RRP9, HERPUD1, CKS1B, EDC4,
